# %%
#i believe it got the thing right
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import LinearNDInterpolator, griddata
import pandas as pd
import time

ds = 0.4

F = 0.6
n = 10
file_path = fr"..\data\unscaled_p\TrP4_{F}_{n}.csv"
# file_path = fr"..\results\test\csv\test_{F}_{n}.csv"

tilt = ds / n

# Define the centers and radius of the circular posts
centers = [(0, 0), (0, ds), (ds, tilt), (ds, ds + tilt)]
radius = F * ds / 2  # radius of pillar nanometers
radius_of_particle = 0.0208
y_s = radius + radius_of_particle + 0.004
wall_distance_threshold = radius_of_particle  # Set the wall distance threshold as a variable


# Create a grid to compute distances
x_range = np.linspace(0, ds, 400)
y_range = np.linspace(0, ds + tilt, 400)
X, Y = np.meshgrid(x_range, y_range)

# Calculate the distance from each point in the grid to the nearest circular post
distances = np.full_like(X, np.inf, dtype=float)  # initialize with infinity

for cx, cy in centers:
    distance_to_post = np.sqrt((X - cx)**2 + (Y - cy)**2) - radius
    distances = np.minimum(distances, distance_to_post)  # take the minimum distance

# Set negative distances to zero
distances = np.maximum(distances, 0)

# Calculate the gradient of the wall distance function
dy, dx = np.gradient(distances, y_range, x_range)

# Calculate the magnitude of the gradient (surface normal)
gradient_magnitude = np.sqrt(dx**2 + dy**2)

# Initialize normal_x and normal_y with zeros
normal_x = np.zeros_like(dx)
normal_y = np.zeros_like(dy)

# Avoid division by zero by normalizing only where gradient_magnitude is not zero
non_zero_magnitude = gradient_magnitude > 0
normal_x[non_zero_magnitude] = dx[non_zero_magnitude] / gradient_magnitude[non_zero_magnitude]
normal_y[non_zero_magnitude] = dy[non_zero_magnitude] / gradient_magnitude[non_zero_magnitude]

# Create LinearNDInterpolators for wall distance and normals
wall_distance_interp = LinearNDInterpolator(list(zip(X.ravel(), Y.ravel())), distances.ravel(), fill_value=np.inf)
normal_x_interp = LinearNDInterpolator(list(zip(X.ravel(), Y.ravel())), normal_x.ravel(), fill_value=0)
normal_y_interp = LinearNDInterpolator(list(zip(X.ravel(), Y.ravel())), normal_y.ravel(), fill_value=0)

# Load the particle velocity data
velocity_field_data = pd.read_csv(file_path)

x = velocity_field_data['x'].values
y = velocity_field_data['y'].values
u = velocity_field_data['u'].values
v = velocity_field_data['v'].values

# Normalize the velocity components
maxu = np.max(np.abs(u))
maxv = np.max(np.abs(v))
max_vel = max(maxu, maxv)

# Create LinearNDInterpolator for U and V fields
u_interp = LinearNDInterpolator(list(zip(x, y)), u / max_vel)  # Normalize during interpolation setup
v_interp = LinearNDInterpolator(list(zip(x, y)), v / max_vel)

def velocity(x, y, u_interp, v_interp):
    """Interpolate velocity at the particle's position."""
    u = u_interp(x, y)
    v = v_interp(x, y)
    return u, v

def rk4_step(x, y, dt, u, v):
    """Calculate the next position of the particle using RK4 with provided velocity components."""
    # k1
    k1x = dt * u
    k1y = dt * v

    # k2
    u2, v2 = velocity(x + k1x / 2, y + k1y / 2, u_interp, v_interp)
    k2x = dt * u2
    k2y = dt * v2

    # k3
    u3, v3 = velocity(x + k2x / 2, y + k2y / 2, u_interp, v_interp)
    k3x = dt * u3
    k3y = dt * v3

    # k4
    u4, v4 = velocity(x + k3x, y + k3y, u_interp, v_interp)
    k4x = dt * u4
    k4y = dt * v4

    # Combine increments to get the next position
    x_next = x + (k1x + 2 * k2x + 2 * k3x + k4x) / 6
    y_next = y + (k1y + 2 * k2y + 2 * k3y + k4y) / 6

    return x_next, y_next

# Initial position of the particle
x0, y0 = 0, y_s  # Starting at x=0, y=142.5
dt = 0.05  # Time step

# Lists to store the particle's trajectory and wall distance
x_traj = [x0]
y_traj = [y0]
wall_distances = []  # To store the wall distance after each iteration

# Start timer for simulation
start_time = time.time()

# Initialize the initial velocity
u, v = velocity(x0, y0, u_interp, v_interp)

# Simulate the particle trajectory with COMSOL-like reflection mode
i = 0
while x_traj[-1] < 0.39999 and y_traj[-1] > 0.00001:
    x_next, y_next = rk4_step(x_traj[-1], y_traj[-1], dt, u, v)
    
    # Interpolate wall distance at the new position
    distance_to_wall = wall_distance_interp(x_next, y_next)
    wall_distances.append(distance_to_wall)  # Append the wall distance to the list
    
    # Check if particle hits the wall (distance <= wall_distance_threshold)
    if distance_to_wall <= wall_distance_threshold:
        # Get the normal vector at the point of collision
        nx = normal_x_interp(x_next, y_next)
        ny = normal_y_interp(x_next, y_next)
        
        # Reflect the velocity according to the COMSOL-style bounce model
        # Calculate the incident angle and reflect the velocity across the normal
        dot_product = u * nx + v * ny
        u = u - 2 * dot_product * nx
        v = v - 2 * dot_product * ny
        
        # Move the particle to exactly wall_distance_threshold away from the wall along the normal direction
        x_next = x_next + (wall_distance_threshold - distance_to_wall) * nx
        y_next = y_next + (wall_distance_threshold - distance_to_wall) * ny
        
        # Update distance to ensure it's precisely at the threshold after moving
        distance_to_wall = wall_distance_interp(x_next, y_next)
    else:
        u, v = velocity(x_next, y_next, u_interp, v_interp)

    if x_next > 0.3995:
        print(f"Iteration {i}: Position (x, y) = ({x_next:.2f}, {y_next:.2f}), Wall Distance = {distance_to_wall:.2f} nm, u = {u:.5f}, v = {v:.5f}")
    
    # Append the updated position after reflection if necessary
    x_traj.append(x_next)
    y_traj.append(y_next)

    # Print position and wall distance every 100 iterations
    i += 1
    if i % 100 == 0:
        print(f"Iteration {i}: Position (x, y) = ({x_next:.2f}, {y_next:.2f}), Wall Distance = {distance_to_wall:.2f} nm, u = {u:.5f}, v = {v:.5f}")

# End timer for simulation
end_time = time.time()
total_time = end_time - start_time
print(f"Total simulation time: {total_time:.2f} seconds")

# Plot the results
plt.figure(figsize=(10, 8))
plt.contourf(X, Y, distances, levels=50, cmap='coolwarm')
plt.colorbar(label='Distance to Wall (nm)')
plt.plot(x_traj, y_traj, 'r-', label='Particle Trajectory')
plt.scatter([x0], [y0], color='red', label='Start Position')
plt.xlabel('X Position (nm)')
plt.ylabel('Y Position (nm)')
plt.legend()
plt.title('CFD Particle Trajectory')
plt.show()
# Out:
# Total simulation time: 10.50 seconds

# %%
#i believe it got the thing right
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import LinearNDInterpolator, griddata
import pandas as pd
import time

ds = 0.4

F = 0.6
n = 10
# file_path = fr"..\data\unscaled_p\TrP4_{F}_{n}.csv"
file_path = fr"..\results\test\csv\test_{F}_{n}.csv"

tilt = ds / n

# Define the centers and radius of the circular posts
centers = [(0, 0), (0, ds), (ds, tilt), (ds, ds + tilt)]
radius = F * ds / 2  # radius of pillar nanometers
radius_of_particle = 0.0208
y_s = radius + radius_of_particle + 0.004
wall_distance_threshold = radius_of_particle  # Set the wall distance threshold as a variable


# Create a grid to compute distances
x_range = np.linspace(0, ds, 400)
y_range = np.linspace(0, ds + tilt, 400)
X, Y = np.meshgrid(x_range, y_range)

# Calculate the distance from each point in the grid to the nearest circular post
distances = np.full_like(X, np.inf, dtype=float)  # initialize with infinity

for cx, cy in centers:
    distance_to_post = np.sqrt((X - cx)**2 + (Y - cy)**2) - radius
    distances = np.minimum(distances, distance_to_post)  # take the minimum distance

# Set negative distances to zero
distances = np.maximum(distances, 0)

# Calculate the gradient of the wall distance function
dy, dx = np.gradient(distances, y_range, x_range)

# Calculate the magnitude of the gradient (surface normal)
gradient_magnitude = np.sqrt(dx**2 + dy**2)

# Initialize normal_x and normal_y with zeros
normal_x = np.zeros_like(dx)
normal_y = np.zeros_like(dy)

# Avoid division by zero by normalizing only where gradient_magnitude is not zero
non_zero_magnitude = gradient_magnitude > 0
normal_x[non_zero_magnitude] = dx[non_zero_magnitude] / gradient_magnitude[non_zero_magnitude]
normal_y[non_zero_magnitude] = dy[non_zero_magnitude] / gradient_magnitude[non_zero_magnitude]

# Create LinearNDInterpolators for wall distance and normals
wall_distance_interp = LinearNDInterpolator(list(zip(X.ravel(), Y.ravel())), distances.ravel(), fill_value=np.inf)
normal_x_interp = LinearNDInterpolator(list(zip(X.ravel(), Y.ravel())), normal_x.ravel(), fill_value=0)
normal_y_interp = LinearNDInterpolator(list(zip(X.ravel(), Y.ravel())), normal_y.ravel(), fill_value=0)

# Load the particle velocity data
velocity_field_data = pd.read_csv(file_path)

x = velocity_field_data['x'].values
y = velocity_field_data['y'].values
u = velocity_field_data['u'].values
v = velocity_field_data['v'].values

# Normalize the velocity components
maxu = np.max(np.abs(u))
maxv = np.max(np.abs(v))
max_vel = max(maxu, maxv)

# Create LinearNDInterpolator for U and V fields
u_interp = LinearNDInterpolator(list(zip(x, y)), u / max_vel)  # Normalize during interpolation setup
v_interp = LinearNDInterpolator(list(zip(x, y)), v / max_vel)

def velocity(x, y, u_interp, v_interp):
    """Interpolate velocity at the particle's position."""
    u = u_interp(x, y)
    v = v_interp(x, y)
    return u, v

def rk4_step(x, y, dt, u, v):
    """Calculate the next position of the particle using RK4 with provided velocity components."""
    # k1
    k1x = dt * u
    k1y = dt * v

    # k2
    u2, v2 = velocity(x + k1x / 2, y + k1y / 2, u_interp, v_interp)
    k2x = dt * u2
    k2y = dt * v2

    # k3
    u3, v3 = velocity(x + k2x / 2, y + k2y / 2, u_interp, v_interp)
    k3x = dt * u3
    k3y = dt * v3

    # k4
    u4, v4 = velocity(x + k3x, y + k3y, u_interp, v_interp)
    k4x = dt * u4
    k4y = dt * v4

    # Combine increments to get the next position
    x_next = x + (k1x + 2 * k2x + 2 * k3x + k4x) / 6
    y_next = y + (k1y + 2 * k2y + 2 * k3y + k4y) / 6

    return x_next, y_next

# Initial position of the particle
x0, y0 = 0, y_s  # Starting at x=0, y=142.5
dt = 0.05  # Time step

# Lists to store the particle's trajectory and wall distance
x_traj = [x0]
y_traj = [y0]
wall_distances = []  # To store the wall distance after each iteration

# Start timer for simulation
start_time = time.time()

# Initialize the initial velocity
u, v = velocity(x0, y0, u_interp, v_interp)

# Simulate the particle trajectory with COMSOL-like reflection mode
i = 0
while x_traj[-1] < 0.39999 and y_traj[-1] > 0.00001:
    x_next, y_next = rk4_step(x_traj[-1], y_traj[-1], dt, u, v)
    
    # Interpolate wall distance at the new position
    distance_to_wall = wall_distance_interp(x_next, y_next)
    wall_distances.append(distance_to_wall)  # Append the wall distance to the list
    
    # Check if particle hits the wall (distance <= wall_distance_threshold)
    if distance_to_wall <= wall_distance_threshold:
        # Get the normal vector at the point of collision
        nx = normal_x_interp(x_next, y_next)
        ny = normal_y_interp(x_next, y_next)
        
        # Reflect the velocity according to the COMSOL-style bounce model
        # Calculate the incident angle and reflect the velocity across the normal
        dot_product = u * nx + v * ny
        u = u - 2 * dot_product * nx
        v = v - 2 * dot_product * ny
        
        # Move the particle to exactly wall_distance_threshold away from the wall along the normal direction
        x_next = x_next + (wall_distance_threshold - distance_to_wall) * nx
        y_next = y_next + (wall_distance_threshold - distance_to_wall) * ny
        
        # Update distance to ensure it's precisely at the threshold after moving
        distance_to_wall = wall_distance_interp(x_next, y_next)
    else:
        u, v = velocity(x_next, y_next, u_interp, v_interp)

    if x_next > 0.3995:
        print(f"Iteration {i}: Position (x, y) = ({x_next:.2f}, {y_next:.2f}), Wall Distance = {distance_to_wall:.2f} nm, u = {u:.5f}, v = {v:.5f}")
    
    # Append the updated position after reflection if necessary
    x_traj.append(x_next)
    y_traj.append(y_next)

    # Print position and wall distance every 100 iterations
    i += 1
    if i % 100 == 0:
        print(f"Iteration {i}: Position (x, y) = ({x_next:.2f}, {y_next:.2f}), Wall Distance = {distance_to_wall:.2f} nm, u = {u:.5f}, v = {v:.5f}")

# End timer for simulation
end_time = time.time()
total_time = end_time - start_time
print(f"Total simulation time: {total_time:.2f} seconds")

# Plot the results
plt.figure(figsize=(10, 8))
plt.contourf(X, Y, distances, levels=50, cmap='coolwarm')
plt.colorbar(label='Distance to Wall (nm)')
plt.plot(x_traj, y_traj, 'r-', label='Particle Trajectory')
plt.scatter([x0], [y0], color='red', label='Start Position')
plt.xlabel('X Position (nm)')
plt.ylabel('Y Position (nm)')
plt.legend()
plt.title('PINN Particle Trajectory')
plt.show()

# %%
#i believe it got the thing right
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import LinearNDInterpolator, griddata
import pandas as pd
import time

# Define the centers and radius of the circular posts
centers = [(0, 0), (0, 400), (400, 40), (400, 440)]
radius = 120  # radius of pillar nanometers
radius_of_particle = 20.2
y_s = radius + radius_of_particle
wall_distance_threshold = radius_of_particle  # Set the wall distance threshold as a variable


# Create a grid to compute distances
x_range = np.linspace(0, 400, 400)
y_range = np.linspace(0, 440, 400)
X, Y = np.meshgrid(x_range, y_range)

# Calculate the distance from each point in the grid to the nearest circular post
distances = np.full_like(X, np.inf, dtype=float)  # initialize with infinity

for cx, cy in centers:
    distance_to_post = np.sqrt((X - cx)**2 + (Y - cy)**2) - radius
    distances = np.minimum(distances, distance_to_post)  # take the minimum distance

# Set negative distances to zero
distances = np.maximum(distances, 0)

# Calculate the gradient of the wall distance function
dy, dx = np.gradient(distances, y_range, x_range)

# Calculate the magnitude of the gradient (surface normal)
gradient_magnitude = np.sqrt(dx**2 + dy**2)

# Initialize normal_x and normal_y with zeros
normal_x = np.zeros_like(dx)
normal_y = np.zeros_like(dy)

# Avoid division by zero by normalizing only where gradient_magnitude is not zero
non_zero_magnitude = gradient_magnitude > 0
normal_x[non_zero_magnitude] = dx[non_zero_magnitude] / gradient_magnitude[non_zero_magnitude]
normal_y[non_zero_magnitude] = dy[non_zero_magnitude] / gradient_magnitude[non_zero_magnitude]

# Create LinearNDInterpolators for wall distance and normals
wall_distance_interp = LinearNDInterpolator(list(zip(X.ravel(), Y.ravel())), distances.ravel(), fill_value=np.inf)
normal_x_interp = LinearNDInterpolator(list(zip(X.ravel(), Y.ravel())), normal_x.ravel(), fill_value=0)
normal_y_interp = LinearNDInterpolator(list(zip(X.ravel(), Y.ravel())), normal_y.ravel(), fill_value=0)

# Load the particle velocity data
file_path = r"C:\Users\mahir\OneDrive\Desktop\Fieldpinc.csv"
velocity_field_data = pd.read_csv(file_path)

x = velocity_field_data['x'].values
y = velocity_field_data['y'].values
u = velocity_field_data['u1x (m/s) @ t=0.01'].values
v = velocity_field_data['u1y (m/s) @ t=0.01'].values

# Normalize the velocity components
maxu = np.max(np.abs(u))
maxv = np.max(np.abs(v))
max_vel = max(maxu, maxv)

# Create LinearNDInterpolator for U and V fields
u_interp = LinearNDInterpolator(list(zip(x, y)), u / max_vel)  # Normalize during interpolation setup
v_interp = LinearNDInterpolator(list(zip(x, y)), v / max_vel)

def velocity(x, y, u_interp, v_interp):
    """Interpolate velocity at the particle's position."""
    u = u_interp(x, y)
    v = v_interp(x, y)
    return u, v

def rk4_step(x, y, dt, u, v):
    """Calculate the next position of the particle using RK4 with provided velocity components."""
    # k1
    k1x = dt * u
    k1y = dt * v

    # k2
    u2, v2 = velocity(x + k1x / 2, y + k1y / 2, u_interp, v_interp)
    k2x = dt * u2
    k2y = dt * v2

    # k3
    u3, v3 = velocity(x + k2x / 2, y + k2y / 2, u_interp, v_interp)
    k3x = dt * u3
    k3y = dt * v3

    # k4
    u4, v4 = velocity(x + k3x, y + k3y, u_interp, v_interp)
    k4x = dt * u4
    k4y = dt * v4

    # Combine increments to get the next position
    x_next = x + (k1x + 2 * k2x + 2 * k3x + k4x) / 6
    y_next = y + (k1y + 2 * k2y + 2 * k3y + k4y) / 6

    return x_next, y_next

# Initial position of the particle
x0, y0 = 0, y_s  # Starting at x=0, y=142.5
dt = 0.1  # Time step

# Lists to store the particle's trajectory and wall distance
x_traj = [x0]
y_traj = [y0]
wall_distances = []  # To store the wall distance after each iteration

# Start timer for simulation
start_time = time.time()

# Initialize the initial velocity
#u, v = velocity(x0, y0, u_interp, v_interp)
u, v = 0, 0
print(f" v = {v:.5f}")

# Simulate the particle trajectory with COMSOL-like reflection mode
i = 0
while x_traj[-1] < 399.99 and y_traj[-1] > 0.01:
    x_next, y_next = rk4_step(x_traj[-1], y_traj[-1], dt, u, v)
    
    # Interpolate wall distance at the new position
    distance_to_wall = wall_distance_interp(x_next, y_next)
    wall_distances.append(distance_to_wall)  # Append the wall distance to the list
    
    # Check if particle hits the wall (distance <= wall_distance_threshold)
    if distance_to_wall <= wall_distance_threshold:
        # Get the normal vector at the point of collision
        nx = normal_x_interp(x_next, y_next)
        ny = normal_y_interp(x_next, y_next)
        
        # Reflect the velocity according to the COMSOL-style bounce model
        # Calculate the incident angle and reflect the velocity across the normal
        dot_product = u * nx + v * ny
        u = u - 2 * dot_product * nx
        v = v - 2 * dot_product * ny
        
        # Move the particle to exactly wall_distance_threshold away from the wall along the normal direction
        x_next = x_next + (wall_distance_threshold - distance_to_wall) * nx
        y_next = y_next + (wall_distance_threshold - distance_to_wall) * ny
        
        # Update distance to ensure it's precisely at the threshold after moving
        distance_to_wall = wall_distance_interp(x_next, y_next)
    else:
        u, v = velocity(x_next, y_next, u_interp, v_interp)
        
    if x_next > 399.5:
        print(f"Iteration {i}: Position (x, y) = ({x_next:.2f}, {y_next:.2f}), u = {u:.5f}, v = {v:.5f} ")

    
    # Append the updated position after reflection if necessary
    x_traj.append(x_next)
    y_traj.append(y_next)

    # Print position and wall distance every 100 iterations
    i += 1
    if i % 100 == 0:
        print(f"Iteration {i}: Position (x, y) = ({x_next:.2f}, {y_next:.2f}), Wall Distance = {distance_to_wall:.2f} nm")

# End timer for simulation
end_time = time.time()
total_time = end_time - start_time
print(f"Total simulation time: {total_time:.2f} seconds")

# Plot the results
plt.figure(figsize=(10, 8))
plt.contourf(X, Y, distances, levels=50, cmap='coolwarm')
plt.colorbar(label='Distance to Wall (nm)')
plt.plot(x_traj, y_traj, 'r-', label='Particle Trajectory')
plt.scatter([x0], [y0], color='red', label='Start Position')
plt.xlabel('X Position (nm)')
plt.ylabel('Y Position (nm)')
plt.legend()
plt.title('Particle Trajectory with COMSOL-Style Reflection Mode')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 53
#      51 # Load the particle velocity data
#      52 file_path = r"C:\Users\mahir\OneDrive\Desktop\Fieldpinc.csv"
# ---> 53 velocity_field_data = pd.read_csv(file_path)
#      55 x = velocity_field_data['x'].values
#      56 y = velocity_field_data['y'].values
#
# File c:\Users\leeyo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\leeyo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\leeyo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\leeyo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\leeyo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\mahir\\OneDrive\\Desktop\\Fieldpinc.csv'

# %%
#i believe it got the thing right
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import LinearNDInterpolator, griddata
import pandas as pd
import time

# Define the centers and radius of the circular posts
centers = [(0, 0), (0, 400), (400, 40), (400, 440)]
radius = 120  # radius of pillar nanometers
radius_of_particle = 20.2
y_s = radius + radius_of_particle
wall_distance_threshold = radius_of_particle  # Set the wall distance threshold as a variable


# Create a grid to compute distances
x_range = np.linspace(0, 400, 400)
y_range = np.linspace(0, 440, 400)
X, Y = np.meshgrid(x_range, y_range)

# Calculate the distance from each point in the grid to the nearest circular post
distances = np.full_like(X, np.inf, dtype=float)  # initialize with infinity

for cx, cy in centers:
    distance_to_post = np.sqrt((X - cx)**2 + (Y - cy)**2) - radius
    distances = np.minimum(distances, distance_to_post)  # take the minimum distance

# Set negative distances to zero
distances = np.maximum(distances, 0)

# Calculate the gradient of the wall distance function
dy, dx = np.gradient(distances, y_range, x_range)

# Calculate the magnitude of the gradient (surface normal)
gradient_magnitude = np.sqrt(dx**2 + dy**2)

# Initialize normal_x and normal_y with zeros
normal_x = np.zeros_like(dx)
normal_y = np.zeros_like(dy)

# Avoid division by zero by normalizing only where gradient_magnitude is not zero
non_zero_magnitude = gradient_magnitude > 0
normal_x[non_zero_magnitude] = dx[non_zero_magnitude] / gradient_magnitude[non_zero_magnitude]
normal_y[non_zero_magnitude] = dy[non_zero_magnitude] / gradient_magnitude[non_zero_magnitude]

# Create LinearNDInterpolators for wall distance and normals
wall_distance_interp = LinearNDInterpolator(list(zip(X.ravel(), Y.ravel())), distances.ravel(), fill_value=np.inf)
normal_x_interp = LinearNDInterpolator(list(zip(X.ravel(), Y.ravel())), normal_x.ravel(), fill_value=0)
normal_y_interp = LinearNDInterpolator(list(zip(X.ravel(), Y.ravel())), normal_y.ravel(), fill_value=0)

# Load the particle velocity data
file_path = r"C:\Users\mahir\OneDrive\Desktop\Fieldpinc.csv"
velocity_field_data = pd.read_csv(file_path)

x = velocity_field_data['x'].values
y = velocity_field_data['y'].values
u = velocity_field_data['u1x (m/s) @ t=0.01'].values
v = velocity_field_data['u1y (m/s) @ t=0.01'].values

# Normalize the velocity components
maxu = np.max(np.abs(u))
maxv = np.max(np.abs(v))
max_vel = max(maxu, maxv)

# Create LinearNDInterpolator for U and V fields
u_interp = LinearNDInterpolator(list(zip(x, y)), u / max_vel)  # Normalize during interpolation setup
v_interp = LinearNDInterpolator(list(zip(x, y)), v / max_vel)

def velocity(x, y, u_interp, v_interp):
    """Interpolate velocity at the particle's position."""
    u = u_interp(x, y)
    v = v_interp(x, y)
    return u, v

def rk4_step(x, y, dt, u, v):
    """Calculate the next position of the particle using RK4 with provided velocity components."""
    # k1
    k1x = dt * u
    k1y = dt * v

    # k2
    u2, v2 = velocity(x + k1x / 2, y + k1y / 2, u_interp, v_interp)
    k2x = dt * u2
    k2y = dt * v2

    # k3
    u3, v3 = velocity(x + k2x / 2, y + k2y / 2, u_interp, v_interp)
    k3x = dt * u3
    k3y = dt * v3

    # k4
    u4, v4 = velocity(x + k3x, y + k3y, u_interp, v_interp)
    k4x = dt * u4
    k4y = dt * v4

    # Combine increments to get the next position
    x_next = x + (k1x + 2 * k2x + 2 * k3x + k4x) / 6
    y_next = y + (k1y + 2 * k2y + 2 * k3y + k4y) / 6

    return x_next, y_next

# Initial position of the particle
x0, y0 = 0, y_s  # Starting at x=0, y=142.5
dt = 0.1  # Time step

# Lists to store the particle's trajectory and wall distance
x_traj = [x0]
y_traj = [y0]
wall_distances = []  # To store the wall distance after each iteration

# Start timer for simulation
start_time = time.time()

# Initialize the initial velocity
#u, v = velocity(x0, y0, u_interp, v_interp)
u, v = 0, 0
print(f" v = {v:.5f}")

# Simulate the particle trajectory with COMSOL-like reflection mode
i = 0
while x_traj[-1] < 399.99 and y_traj[-1] > 0.01:
    x_next, y_next = rk4_step(x_traj[-1], y_traj[-1], dt, u, v)
    
    # Interpolate wall distance at the new position
    distance_to_wall = wall_distance_interp(x_next, y_next)
    wall_distances.append(distance_to_wall)  # Append the wall distance to the list
    
    # Check if particle hits the wall (distance <= wall_distance_threshold)
    if distance_to_wall <= wall_distance_threshold:
        # Get the normal vector at the point of collision
        nx = normal_x_interp(x_next, y_next)
        ny = normal_y_interp(x_next, y_next)
        
        # Reflect the velocity according to the COMSOL-style bounce model
        # Calculate the incident angle and reflect the velocity across the normal
        dot_product = u * nx + v * ny
        u = u - 2 * dot_product * nx
        v = v - 2 * dot_product * ny
        
        # Move the particle to exactly wall_distance_threshold away from the wall along the normal direction
        x_next = x_next + (wall_distance_threshold - distance_to_wall) * nx
        y_next = y_next + (wall_distance_threshold - distance_to_wall) * ny
        
        # Update distance to ensure it's precisely at the threshold after moving
        distance_to_wall = wall_distance_interp(x_next, y_next)
    else:
        u, v = velocity(x_next, y_next, u_interp, v_interp)
        
    if x_next > 399.5:
        print(f"Iteration {i}: Position (x, y) = ({x_next:.2f}, {y_next:.2f}), u = {u:.5f}, v = {v:.5f} ")

    
    # Append the updated position after reflection if necessary
    x_traj.append(x_next)
    y_traj.append(y_next)

    # Print position and wall distance every 100 iterations
    i += 1
    if i % 100 == 0:
        print(f"Iteration {i}: Position (x, y) = ({x_next:.2f}, {y_next:.2f}), Wall Distance = {distance_to_wall:.2f} nm")

# End timer for simulation
end_time = time.time()
total_time = end_time - start_time
print(f"Total simulation time: {total_time:.2f} seconds")

# Plot the results
plt.figure(figsize=(10, 8))
plt.contourf(X, Y, distances, levels=50, cmap='coolwarm')
plt.colorbar(label='Distance to Wall (nm)')
plt.plot(x_traj, y_traj, 'r-', label='Particle Trajectory')
plt.scatter([x0], [y0], color='red', label='Start Position')
plt.xlabel('X Position (nm)')
plt.ylabel('Y Position (nm)')
plt.legend()
plt.title('Particle Trajectory with COMSOL-Style Reflection Mode')
plt.show()
# Out:
#  v = 0.00000
# Iteration 100: Position (x, y) = (5.01, 140.14), Wall Distance = 20.23 nm
# Iteration 200: Position (x, y) = (10.01, 139.96), Wall Distance = 20.32 nm
# Iteration 300: Position (x, y) = (14.97, 139.66), Wall Distance = 20.46 nm
# Iteration 400: Position (x, y) = (19.89, 139.24), Wall Distance = 20.66 nm
# Iteration 500: Position (x, y) = (24.74, 138.71), Wall Distance = 20.90 nm
# Iteration 600: Position (x, y) = (29.52, 138.08), Wall Distance = 21.20 nm
# Iteration 700: Position (x, y) = (34.22, 137.34), Wall Distance = 21.54 nm
# Iteration 800: Position (x, y) = (38.82, 136.52), Wall Distance = 21.93 nm
# Iteration 900: Position (x, y) = (43.32, 135.62), Wall Distance = 22.37 nm
# Iteration 1000: Position (x, y) = (47.72, 134.64), Wall Distance = 22.84 nm
# Iteration 1100: Position (x, y) = (52.00, 133.60), Wall Distance = 23.36 nm
# Iteration 1200: Position (x, y) = (56.16, 132.50), Wall Distance = 23.91 nm
# Iteration 1300: Position (x, y) = (60.22, 131.36), Wall Distance = 24.50 nm
# Iteration 1400: Position (x, y) = (64.16, 130.18), Wall Distance = 25.13 nm
# Iteration 1500: Position (x, y) = (67.98, 128.96), Wall Distance = 25.78 nm
# Iteration 1600: Position (x, y) = (71.69, 127.73), Wall Distance = 26.48 nm
# Iteration 1700: Position (x, y) = (75.30, 126.48), Wall Distance = 27.20 nm
# Iteration 1800: Position (x, y) = (78.80, 125.22), Wall Distance = 27.95 nm
# Iteration 1900: Position (x, y) = (82.19, 123.95), Wall Distance = 28.73 nm
# Iteration 2000: Position (x, y) = (85.49, 122.68), Wall Distance = 29.53 nm
# Iteration 2100: Position (x, y) = (88.69, 121.42), Wall Distance = 30.36 nm
# Iteration 2200: Position (x, y) = (91.80, 120.16), Wall Distance = 31.22 nm
# Iteration 2300: Position (x, y) = (94.83, 118.92), Wall Distance = 32.10 nm
# Iteration 2400: Position (x, y) = (97.77, 117.69), Wall Distance = 33.00 nm
# Iteration 2500: Position (x, y) = (100.64, 116.47), Wall Distance = 33.93 nm
# Iteration 2600: Position (x, y) = (103.43, 115.28), Wall Distance = 34.88 nm
# Iteration 2700: Position (x, y) = (106.15, 114.10), Wall Distance = 35.84 nm
# Iteration 2800: Position (x, y) = (108.80, 112.94), Wall Distance = 36.83 nm
# Iteration 2900: Position (x, y) = (111.39, 111.81), Wall Distance = 37.83 nm
# Iteration 3000: Position (x, y) = (113.92, 110.69), Wall Distance = 38.85 nm
# Iteration 3100: Position (x, y) = (116.40, 109.60), Wall Distance = 39.88 nm
# Iteration 3200: Position (x, y) = (118.81, 108.54), Wall Distance = 40.93 nm
# Iteration 3300: Position (x, y) = (121.18, 107.50), Wall Distance = 41.99 nm
# Iteration 3400: Position (x, y) = (123.50, 106.48), Wall Distance = 43.06 nm
# Iteration 3500: Position (x, y) = (125.77, 105.48), Wall Distance = 44.15 nm
# Iteration 3600: Position (x, y) = (127.99, 104.51), Wall Distance = 45.24 nm
# Iteration 3700: Position (x, y) = (130.17, 103.56), Wall Distance = 46.35 nm
# Iteration 3800: Position (x, y) = (132.32, 102.64), Wall Distance = 47.46 nm
# Iteration 3900: Position (x, y) = (134.42, 101.74), Wall Distance = 48.58 nm
# Iteration 4000: Position (x, y) = (136.48, 100.86), Wall Distance = 49.70 nm
# Iteration 4100: Position (x, y) = (138.51, 100.00), Wall Distance = 50.83 nm
# Iteration 4200: Position (x, y) = (140.50, 99.16), Wall Distance = 51.97 nm
# Iteration 4300: Position (x, y) = (142.46, 98.35), Wall Distance = 53.11 nm
# Iteration 4400: Position (x, y) = (144.38, 97.55), Wall Distance = 54.25 nm
# Iteration 4500: Position (x, y) = (146.27, 96.78), Wall Distance = 55.39 nm
# Iteration 4600: Position (x, y) = (148.13, 96.03), Wall Distance = 56.54 nm
# Iteration 4700: Position (x, y) = (149.96, 95.29), Wall Distance = 57.68 nm
# Iteration 4800: Position (x, y) = (151.77, 94.58), Wall Distance = 58.83 nm
# Iteration 4900: Position (x, y) = (153.54, 93.88), Wall Distance = 59.97 nm
# Iteration 5000: Position (x, y) = (155.29, 93.20), Wall Distance = 61.11 nm
# Iteration 5100: Position (x, y) = (157.00, 92.54), Wall Distance = 62.25 nm
# Iteration 5200: Position (x, y) = (158.69, 91.90), Wall Distance = 63.38 nm
# Iteration 5300: Position (x, y) = (160.36, 91.27), Wall Distance = 64.51 nm
# Iteration 5400: Position (x, y) = (162.00, 90.66), Wall Distance = 65.64 nm
# Iteration 5500: Position (x, y) = (163.61, 90.06), Wall Distance = 66.76 nm
# Iteration 5600: Position (x, y) = (165.20, 89.48), Wall Distance = 67.88 nm
# Iteration 5700: Position (x, y) = (166.77, 88.92), Wall Distance = 68.99 nm
# Iteration 5800: Position (x, y) = (168.31, 88.37), Wall Distance = 70.10 nm
# Iteration 5900: Position (x, y) = (169.83, 87.83), Wall Distance = 71.20 nm
# Iteration 6000: Position (x, y) = (171.32, 87.31), Wall Distance = 72.29 nm
# Iteration 6100: Position (x, y) = (172.80, 86.81), Wall Distance = 73.38 nm
# Iteration 6200: Position (x, y) = (174.25, 86.31), Wall Distance = 74.45 nm
# Iteration 6300: Position (x, y) = (175.68, 85.83), Wall Distance = 75.52 nm
# Iteration 6400: Position (x, y) = (177.08, 85.36), Wall Distance = 76.58 nm
# Iteration 6500: Position (x, y) = (178.47, 84.91), Wall Distance = 77.64 nm
# Iteration 6600: Position (x, y) = (179.83, 84.46), Wall Distance = 78.68 nm
# Iteration 6700: Position (x, y) = (181.18, 84.03), Wall Distance = 79.72 nm
# Iteration 6800: Position (x, y) = (182.50, 83.61), Wall Distance = 80.74 nm
# Iteration 6900: Position (x, y) = (183.81, 83.20), Wall Distance = 81.76 nm
# Iteration 7000: Position (x, y) = (185.09, 82.80), Wall Distance = 82.77 nm
# Iteration 7100: Position (x, y) = (186.36, 82.41), Wall Distance = 83.77 nm
# Iteration 7200: Position (x, y) = (187.61, 82.04), Wall Distance = 84.76 nm
# Iteration 7300: Position (x, y) = (188.83, 81.67), Wall Distance = 85.74 nm
# Iteration 7400: Position (x, y) = (190.04, 81.31), Wall Distance = 86.71 nm
# Iteration 7500: Position (x, y) = (191.23, 80.96), Wall Distance = 87.67 nm
# Iteration 7600: Position (x, y) = (192.41, 80.62), Wall Distance = 88.62 nm
# Iteration 7700: Position (x, y) = (193.56, 80.29), Wall Distance = 89.47 nm
# Iteration 7800: Position (x, y) = (194.70, 79.97), Wall Distance = 89.16 nm
# Iteration 7900: Position (x, y) = (195.82, 79.66), Wall Distance = 88.00 nm
# Iteration 8000: Position (x, y) = (196.92, 79.35), Wall Distance = 86.85 nm
# Iteration 8100: Position (x, y) = (198.01, 79.06), Wall Distance = 85.73 nm
# Iteration 8200: Position (x, y) = (199.08, 78.77), Wall Distance = 84.63 nm
# Iteration 8300: Position (x, y) = (200.13, 78.49), Wall Distance = 83.54 nm
# Iteration 8400: Position (x, y) = (201.17, 78.21), Wall Distance = 82.47 nm
# Iteration 8500: Position (x, y) = (202.19, 77.95), Wall Distance = 81.41 nm
# Iteration 8600: Position (x, y) = (203.20, 77.69), Wall Distance = 80.38 nm
# Iteration 8700: Position (x, y) = (204.19, 77.44), Wall Distance = 79.35 nm
# Iteration 8800: Position (x, y) = (205.17, 77.19), Wall Distance = 78.35 nm
# Iteration 8900: Position (x, y) = (206.13, 76.95), Wall Distance = 77.36 nm
# Iteration 9000: Position (x, y) = (207.08, 76.72), Wall Distance = 76.39 nm
# Iteration 9100: Position (x, y) = (208.01, 76.49), Wall Distance = 75.43 nm
# Iteration 9200: Position (x, y) = (208.92, 76.27), Wall Distance = 74.49 nm
# Iteration 9300: Position (x, y) = (209.83, 76.05), Wall Distance = 73.56 nm
# Iteration 9400: Position (x, y) = (210.72, 75.84), Wall Distance = 72.65 nm
# Iteration 9500: Position (x, y) = (211.59, 75.64), Wall Distance = 71.75 nm
# Iteration 9600: Position (x, y) = (212.46, 75.44), Wall Distance = 70.86 nm
# Iteration 9700: Position (x, y) = (213.31, 75.25), Wall Distance = 69.99 nm
# Iteration 9800: Position (x, y) = (214.14, 75.06), Wall Distance = 69.14 nm
# Iteration 9900: Position (x, y) = (214.97, 74.88), Wall Distance = 68.29 nm
# Iteration 10000: Position (x, y) = (215.78, 74.70), Wall Distance = 67.46 nm
# Iteration 10100: Position (x, y) = (216.57, 74.52), Wall Distance = 66.65 nm
# Iteration 10200: Position (x, y) = (217.36, 74.35), Wall Distance = 65.84 nm
# Iteration 10300: Position (x, y) = (218.13, 74.19), Wall Distance = 65.05 nm
# Iteration 10400: Position (x, y) = (218.90, 74.02), Wall Distance = 64.27 nm
# Iteration 10500: Position (x, y) = (219.65, 73.87), Wall Distance = 63.51 nm
# Iteration 10600: Position (x, y) = (220.38, 73.71), Wall Distance = 62.75 nm
# Iteration 10700: Position (x, y) = (221.11, 73.56), Wall Distance = 62.01 nm
# Iteration 10800: Position (x, y) = (221.83, 73.42), Wall Distance = 61.28 nm
# Iteration 10900: Position (x, y) = (222.53, 73.27), Wall Distance = 60.56 nm
# Iteration 11000: Position (x, y) = (223.23, 73.13), Wall Distance = 59.85 nm
# Iteration 11100: Position (x, y) = (223.91, 73.00), Wall Distance = 59.16 nm
# Iteration 11200: Position (x, y) = (224.58, 72.86), Wall Distance = 58.47 nm
# Iteration 11300: Position (x, y) = (225.25, 72.73), Wall Distance = 57.79 nm
# Iteration 11400: Position (x, y) = (225.90, 72.61), Wall Distance = 57.13 nm
# Iteration 11500: Position (x, y) = (226.54, 72.48), Wall Distance = 56.48 nm
# Iteration 11600: Position (x, y) = (227.17, 72.36), Wall Distance = 55.83 nm
# Iteration 11700: Position (x, y) = (227.80, 72.25), Wall Distance = 55.20 nm
# Iteration 11800: Position (x, y) = (228.41, 72.13), Wall Distance = 54.57 nm
# Iteration 11900: Position (x, y) = (229.01, 72.02), Wall Distance = 53.96 nm
# Iteration 12000: Position (x, y) = (229.61, 71.91), Wall Distance = 53.36 nm
# Iteration 12100: Position (x, y) = (230.19, 71.80), Wall Distance = 52.76 nm
# Iteration 12200: Position (x, y) = (230.77, 71.69), Wall Distance = 52.18 nm
# Iteration 12300: Position (x, y) = (231.33, 71.59), Wall Distance = 51.60 nm
# Iteration 12400: Position (x, y) = (231.89, 71.49), Wall Distance = 51.03 nm
# Iteration 12500: Position (x, y) = (232.44, 71.39), Wall Distance = 50.47 nm
# Iteration 12600: Position (x, y) = (232.98, 71.29), Wall Distance = 49.92 nm
# Iteration 12700: Position (x, y) = (233.52, 71.20), Wall Distance = 49.38 nm
# Iteration 12800: Position (x, y) = (234.04, 71.11), Wall Distance = 48.85 nm
# Iteration 12900: Position (x, y) = (234.56, 71.01), Wall Distance = 48.32 nm
# Iteration 13000: Position (x, y) = (235.07, 70.92), Wall Distance = 47.80 nm
# Iteration 13100: Position (x, y) = (235.57, 70.84), Wall Distance = 47.30 nm
# Iteration 13200: Position (x, y) = (236.07, 70.75), Wall Distance = 46.79 nm
# Iteration 13300: Position (x, y) = (236.55, 70.67), Wall Distance = 46.30 nm
# Iteration 13400: Position (x, y) = (237.03, 70.58), Wall Distance = 45.81 nm
# Iteration 13500: Position (x, y) = (237.50, 70.50), Wall Distance = 45.34 nm
# Iteration 13600: Position (x, y) = (237.97, 70.42), Wall Distance = 44.87 nm
# Iteration 13700: Position (x, y) = (238.42, 70.34), Wall Distance = 44.40 nm
# Iteration 13800: Position (x, y) = (238.87, 70.27), Wall Distance = 43.94 nm
# Iteration 13900: Position (x, y) = (239.32, 70.19), Wall Distance = 43.49 nm
# Iteration 14000: Position (x, y) = (239.75, 70.11), Wall Distance = 43.05 nm
# Iteration 14100: Position (x, y) = (240.18, 70.04), Wall Distance = 42.62 nm
# Iteration 14200: Position (x, y) = (240.61, 69.97), Wall Distance = 42.19 nm
# Iteration 14300: Position (x, y) = (241.03, 69.90), Wall Distance = 41.76 nm
# Iteration 14400: Position (x, y) = (241.44, 69.83), Wall Distance = 41.34 nm
# Iteration 14500: Position (x, y) = (241.84, 69.76), Wall Distance = 40.93 nm
# Iteration 14600: Position (x, y) = (242.24, 69.69), Wall Distance = 40.53 nm
# Iteration 14700: Position (x, y) = (242.64, 69.62), Wall Distance = 40.13 nm
# Iteration 14800: Position (x, y) = (243.02, 69.56), Wall Distance = 39.74 nm
# Iteration 14900: Position (x, y) = (243.40, 69.49), Wall Distance = 39.35 nm
# Iteration 15000: Position (x, y) = (243.78, 69.43), Wall Distance = 38.97 nm
# Iteration 15100: Position (x, y) = (244.15, 69.36), Wall Distance = 38.59 nm
# Iteration 15200: Position (x, y) = (244.51, 69.30), Wall Distance = 38.22 nm
# Iteration 15300: Position (x, y) = (244.87, 69.24), Wall Distance = 37.86 nm
# Iteration 15400: Position (x, y) = (245.23, 69.17), Wall Distance = 37.50 nm
# Iteration 15500: Position (x, y) = (245.58, 69.11), Wall Distance = 37.14 nm
# Iteration 15600: Position (x, y) = (245.92, 69.05), Wall Distance = 36.80 nm
# Iteration 15700: Position (x, y) = (246.26, 68.99), Wall Distance = 36.45 nm
# Iteration 15800: Position (x, y) = (246.59, 68.93), Wall Distance = 36.11 nm
# Iteration 15900: Position (x, y) = (246.92, 68.87), Wall Distance = 35.78 nm
# Iteration 16000: Position (x, y) = (247.24, 68.82), Wall Distance = 35.45 nm
# Iteration 16100: Position (x, y) = (247.56, 68.76), Wall Distance = 35.13 nm
# Iteration 16200: Position (x, y) = (247.88, 68.70), Wall Distance = 34.81 nm
# Iteration 16300: Position (x, y) = (248.19, 68.64), Wall Distance = 34.49 nm
# Iteration 16400: Position (x, y) = (248.49, 68.59), Wall Distance = 34.18 nm
# Iteration 16500: Position (x, y) = (248.79, 68.53), Wall Distance = 33.88 nm
# Iteration 16600: Position (x, y) = (249.09, 68.47), Wall Distance = 33.58 nm
# Iteration 16700: Position (x, y) = (249.38, 68.42), Wall Distance = 33.28 nm
# Iteration 16800: Position (x, y) = (249.67, 68.36), Wall Distance = 32.99 nm
# Iteration 16900: Position (x, y) = (249.95, 68.31), Wall Distance = 32.70 nm
# Iteration 17000: Position (x, y) = (250.23, 68.25), Wall Distance = 32.41 nm
# Iteration 17100: Position (x, y) = (250.50, 68.20), Wall Distance = 32.13 nm
# Iteration 17200: Position (x, y) = (250.78, 68.15), Wall Distance = 31.86 nm
# Iteration 17300: Position (x, y) = (251.04, 68.09), Wall Distance = 31.58 nm
# Iteration 17400: Position (x, y) = (251.31, 68.04), Wall Distance = 31.31 nm
# Iteration 17500: Position (x, y) = (251.57, 67.98), Wall Distance = 31.05 nm
# Iteration 17600: Position (x, y) = (251.82, 67.93), Wall Distance = 30.79 nm
# Iteration 17700: Position (x, y) = (252.07, 67.88), Wall Distance = 30.53 nm
# Iteration 17800: Position (x, y) = (252.32, 67.83), Wall Distance = 30.28 nm
# Iteration 17900: Position (x, y) = (252.57, 67.77), Wall Distance = 30.03 nm
# Iteration 18000: Position (x, y) = (252.81, 67.72), Wall Distance = 29.78 nm
# Iteration 18100: Position (x, y) = (253.05, 67.67), Wall Distance = 29.53 nm
# Iteration 18200: Position (x, y) = (253.28, 67.61), Wall Distance = 29.29 nm
# Iteration 18300: Position (x, y) = (253.52, 67.56), Wall Distance = 29.06 nm
# Iteration 18400: Position (x, y) = (253.74, 67.51), Wall Distance = 28.82 nm
# Iteration 18500: Position (x, y) = (253.97, 67.46), Wall Distance = 28.59 nm
# Iteration 18600: Position (x, y) = (254.19, 67.41), Wall Distance = 28.36 nm
# Iteration 18700: Position (x, y) = (254.41, 67.35), Wall Distance = 28.14 nm
# Iteration 18800: Position (x, y) = (254.62, 67.30), Wall Distance = 27.92 nm
# Iteration 18900: Position (x, y) = (254.84, 67.25), Wall Distance = 27.70 nm
# Iteration 19000: Position (x, y) = (255.05, 67.20), Wall Distance = 27.48 nm
# Iteration 19100: Position (x, y) = (255.25, 67.14), Wall Distance = 27.27 nm
# Iteration 19200: Position (x, y) = (255.46, 67.09), Wall Distance = 27.06 nm
# Iteration 19300: Position (x, y) = (255.66, 67.04), Wall Distance = 26.85 nm
# Iteration 19400: Position (x, y) = (255.86, 66.99), Wall Distance = 26.65 nm
# Iteration 19500: Position (x, y) = (256.05, 66.93), Wall Distance = 26.45 nm
# Iteration 19600: Position (x, y) = (256.24, 66.88), Wall Distance = 26.25 nm
# Iteration 19700: Position (x, y) = (256.43, 66.83), Wall Distance = 26.05 nm
# Iteration 19800: Position (x, y) = (256.62, 66.78), Wall Distance = 25.86 nm
# Iteration 19900: Position (x, y) = (256.80, 66.72), Wall Distance = 25.67 nm
# Iteration 20000: Position (x, y) = (256.99, 66.67), Wall Distance = 25.48 nm
# Iteration 20100: Position (x, y) = (257.17, 66.62), Wall Distance = 25.29 nm
# Iteration 20200: Position (x, y) = (257.34, 66.56), Wall Distance = 25.11 nm
# Iteration 20300: Position (x, y) = (257.52, 66.51), Wall Distance = 24.93 nm
# Iteration 20400: Position (x, y) = (257.69, 66.46), Wall Distance = 24.75 nm
# Iteration 20500: Position (x, y) = (257.86, 66.40), Wall Distance = 24.57 nm
# Iteration 20600: Position (x, y) = (258.03, 66.35), Wall Distance = 24.40 nm
# Iteration 20700: Position (x, y) = (258.19, 66.30), Wall Distance = 24.23 nm
# Iteration 20800: Position (x, y) = (258.35, 66.24), Wall Distance = 24.06 nm
# Iteration 20900: Position (x, y) = (258.51, 66.19), Wall Distance = 23.89 nm
# Iteration 21000: Position (x, y) = (258.67, 66.13), Wall Distance = 23.72 nm
# Iteration 21100: Position (x, y) = (258.83, 66.08), Wall Distance = 23.56 nm
# Iteration 21200: Position (x, y) = (258.98, 66.02), Wall Distance = 23.40 nm
# Iteration 21300: Position (x, y) = (259.13, 65.97), Wall Distance = 23.24 nm
# Iteration 21400: Position (x, y) = (259.28, 65.91), Wall Distance = 23.08 nm
# Iteration 21500: Position (x, y) = (259.43, 65.86), Wall Distance = 22.93 nm
# Iteration 21600: Position (x, y) = (259.58, 65.80), Wall Distance = 22.77 nm
# Iteration 21700: Position (x, y) = (259.72, 65.75), Wall Distance = 22.62 nm
# Iteration 21800: Position (x, y) = (259.86, 65.69), Wall Distance = 22.47 nm
# Iteration 21900: Position (x, y) = (260.00, 65.64), Wall Distance = 22.33 nm
# Iteration 22000: Position (x, y) = (260.14, 65.58), Wall Distance = 22.18 nm
# Iteration 22100: Position (x, y) = (260.28, 65.52), Wall Distance = 22.04 nm
# Iteration 22200: Position (x, y) = (260.41, 65.46), Wall Distance = 21.89 nm
# Iteration 22300: Position (x, y) = (260.54, 65.41), Wall Distance = 21.75 nm
# Iteration 22400: Position (x, y) = (260.67, 65.35), Wall Distance = 21.62 nm
# Iteration 22500: Position (x, y) = (260.80, 65.29), Wall Distance = 21.48 nm
# Iteration 22600: Position (x, y) = (260.93, 65.23), Wall Distance = 21.34 nm
# Iteration 22700: Position (x, y) = (261.05, 65.17), Wall Distance = 21.21 nm
# Iteration 22800: Position (x, y) = (261.18, 65.11), Wall Distance = 21.08 nm
# Iteration 22900: Position (x, y) = (261.30, 65.06), Wall Distance = 20.95 nm
# Iteration 23000: Position (x, y) = (261.42, 65.00), Wall Distance = 20.82 nm
# Iteration 23100: Position (x, y) = (261.54, 64.94), Wall Distance = 20.69 nm
# Iteration 23200: Position (x, y) = (261.65, 64.88), Wall Distance = 20.56 nm
# Iteration 23300: Position (x, y) = (261.77, 64.82), Wall Distance = 20.44 nm
# Iteration 23400: Position (x, y) = (261.88, 64.76), Wall Distance = 20.32 nm
# Iteration 23500: Position (x, y) = (261.99, 64.70), Wall Distance = 20.20 nm
# Iteration 23600: Position (x, y) = (261.99, 64.66), Wall Distance = 20.20 nm
# Iteration 23700: Position (x, y) = (261.98, 64.62), Wall Distance = 20.20 nm
# Iteration 23800: Position (x, y) = (261.97, 64.58), Wall Distance = 20.20 nm
# Iteration 23900: Position (x, y) = (261.97, 64.54), Wall Distance = 20.20 nm
# Iteration 24000: Position (x, y) = (261.96, 64.49), Wall Distance = 20.20 nm
# Iteration 24100: Position (x, y) = (261.95, 64.45), Wall Distance = 20.20 nm
# Iteration 24200: Position (x, y) = (261.94, 64.41), Wall Distance = 20.20 nm
# Iteration 24300: Position (x, y) = (261.94, 64.37), Wall Distance = 20.20 nm
# Iteration 24400: Position (x, y) = (261.93, 64.33), Wall Distance = 20.20 nm
# Iteration 24500: Position (x, y) = (261.92, 64.28), Wall Distance = 20.20 nm
# Iteration 24600: Position (x, y) = (261.91, 64.24), Wall Distance = 20.20 nm
# Iteration 24700: Position (x, y) = (261.90, 64.20), Wall Distance = 20.20 nm
# Iteration 24800: Position (x, y) = (261.90, 64.15), Wall Distance = 20.20 nm
# Iteration 24900: Position (x, y) = (261.89, 64.11), Wall Distance = 20.20 nm
# Iteration 25000: Position (x, y) = (261.88, 64.06), Wall Distance = 20.20 nm
# Iteration 25100: Position (x, y) = (261.87, 64.01), Wall Distance = 20.20 nm
# Iteration 25200: Position (x, y) = (261.86, 63.97), Wall Distance = 20.20 nm
# Iteration 25300: Position (x, y) = (261.86, 63.92), Wall Distance = 20.20 nm
# Iteration 25400: Position (x, y) = (261.85, 63.87), Wall Distance = 20.20 nm
# Iteration 25500: Position (x, y) = (261.84, 63.83), Wall Distance = 20.20 nm
# Iteration 25600: Position (x, y) = (261.83, 63.78), Wall Distance = 20.20 nm
# Iteration 25700: Position (x, y) = (261.82, 63.73), Wall Distance = 20.20 nm
# Iteration 25800: Position (x, y) = (261.82, 63.68), Wall Distance = 20.20 nm
# Iteration 25900: Position (x, y) = (261.81, 63.63), Wall Distance = 20.20 nm
# Iteration 26000: Position (x, y) = (261.80, 63.58), Wall Distance = 20.20 nm
# Iteration 26100: Position (x, y) = (261.79, 63.53), Wall Distance = 20.20 nm
# Iteration 26200: Position (x, y) = (261.78, 63.48), Wall Distance = 20.20 nm
# Iteration 26300: Position (x, y) = (261.77, 63.43), Wall Distance = 20.20 nm
# Iteration 26400: Position (x, y) = (261.76, 63.38), Wall Distance = 20.20 nm
# Iteration 26500: Position (x, y) = (261.75, 63.32), Wall Distance = 20.20 nm
# Iteration 26600: Position (x, y) = (261.75, 63.27), Wall Distance = 20.20 nm
# Iteration 26700: Position (x, y) = (261.74, 63.22), Wall Distance = 20.20 nm
# Iteration 26800: Position (x, y) = (261.73, 63.17), Wall Distance = 20.20 nm
# Iteration 26900: Position (x, y) = (261.72, 63.11), Wall Distance = 20.20 nm
# Iteration 27000: Position (x, y) = (261.71, 63.06), Wall Distance = 20.20 nm
# Iteration 27100: Position (x, y) = (261.70, 63.00), Wall Distance = 20.20 nm
# Iteration 27200: Position (x, y) = (261.69, 62.95), Wall Distance = 20.20 nm
# Iteration 27300: Position (x, y) = (261.68, 62.89), Wall Distance = 20.20 nm
# Iteration 27400: Position (x, y) = (261.67, 62.83), Wall Distance = 20.20 nm
# Iteration 27500: Position (x, y) = (261.66, 62.78), Wall Distance = 20.20 nm
# Iteration 27600: Position (x, y) = (261.65, 62.72), Wall Distance = 20.20 nm
# Iteration 27700: Position (x, y) = (261.64, 62.66), Wall Distance = 20.20 nm
# Iteration 27800: Position (x, y) = (261.63, 62.60), Wall Distance = 20.20 nm
# Iteration 27900: Position (x, y) = (261.62, 62.54), Wall Distance = 20.20 nm
# Iteration 28000: Position (x, y) = (261.62, 62.48), Wall Distance = 20.20 nm
# Iteration 28100: Position (x, y) = (261.61, 62.42), Wall Distance = 20.20 nm
# Iteration 28200: Position (x, y) = (261.60, 62.36), Wall Distance = 20.20 nm
# Iteration 28300: Position (x, y) = (261.59, 62.30), Wall Distance = 20.20 nm
# Iteration 28400: Position (x, y) = (261.58, 62.24), Wall Distance = 20.20 nm
# Iteration 28500: Position (x, y) = (261.57, 62.17), Wall Distance = 20.20 nm
# Iteration 28600: Position (x, y) = (261.56, 62.11), Wall Distance = 20.20 nm
# Iteration 28700: Position (x, y) = (261.55, 62.05), Wall Distance = 20.20 nm
# Iteration 28800: Position (x, y) = (261.54, 61.98), Wall Distance = 20.20 nm
# Iteration 28900: Position (x, y) = (261.52, 61.92), Wall Distance = 20.20 nm
# Iteration 29000: Position (x, y) = (261.51, 61.85), Wall Distance = 20.20 nm
# Iteration 29100: Position (x, y) = (261.50, 61.79), Wall Distance = 20.20 nm
# Iteration 29200: Position (x, y) = (261.49, 61.72), Wall Distance = 20.20 nm
# Iteration 29300: Position (x, y) = (261.48, 61.65), Wall Distance = 20.20 nm
# Iteration 29400: Position (x, y) = (261.47, 61.59), Wall Distance = 20.20 nm
# Iteration 29500: Position (x, y) = (261.46, 61.52), Wall Distance = 20.20 nm
# Iteration 29600: Position (x, y) = (261.45, 61.45), Wall Distance = 20.20 nm
# Iteration 29700: Position (x, y) = (261.44, 61.38), Wall Distance = 20.20 nm
# Iteration 29800: Position (x, y) = (261.43, 61.31), Wall Distance = 20.20 nm
# Iteration 29900: Position (x, y) = (261.42, 61.24), Wall Distance = 20.20 nm
# Iteration 30000: Position (x, y) = (261.41, 61.17), Wall Distance = 20.20 nm
# Iteration 30100: Position (x, y) = (261.40, 61.10), Wall Distance = 20.20 nm
# Iteration 30200: Position (x, y) = (261.39, 61.03), Wall Distance = 20.20 nm
# Iteration 30300: Position (x, y) = (261.38, 60.95), Wall Distance = 20.20 nm
# Iteration 30400: Position (x, y) = (261.36, 60.88), Wall Distance = 20.20 nm
# Iteration 30500: Position (x, y) = (261.35, 60.81), Wall Distance = 20.20 nm
# Iteration 30600: Position (x, y) = (261.34, 60.73), Wall Distance = 20.20 nm
# Iteration 30700: Position (x, y) = (261.33, 60.66), Wall Distance = 20.20 nm
# Iteration 30800: Position (x, y) = (261.32, 60.58), Wall Distance = 20.20 nm
# Iteration 30900: Position (x, y) = (261.31, 60.50), Wall Distance = 20.20 nm
# Iteration 31000: Position (x, y) = (261.30, 60.43), Wall Distance = 20.20 nm
# Iteration 31100: Position (x, y) = (261.29, 60.35), Wall Distance = 20.20 nm
# Iteration 31200: Position (x, y) = (261.27, 60.27), Wall Distance = 20.20 nm
# Iteration 31300: Position (x, y) = (261.26, 60.19), Wall Distance = 20.20 nm
# Iteration 31400: Position (x, y) = (261.25, 60.11), Wall Distance = 20.20 nm
# Iteration 31500: Position (x, y) = (261.24, 60.03), Wall Distance = 20.20 nm
# Iteration 31600: Position (x, y) = (261.23, 59.95), Wall Distance = 20.20 nm
# Iteration 31700: Position (x, y) = (261.22, 59.87), Wall Distance = 20.20 nm
# Iteration 31800: Position (x, y) = (261.20, 59.78), Wall Distance = 20.20 nm
# Iteration 31900: Position (x, y) = (261.19, 59.70), Wall Distance = 20.20 nm
# Iteration 32000: Position (x, y) = (261.18, 59.62), Wall Distance = 20.20 nm
# Iteration 32100: Position (x, y) = (261.17, 59.53), Wall Distance = 20.20 nm
# Iteration 32200: Position (x, y) = (261.16, 59.45), Wall Distance = 20.20 nm
# Iteration 32300: Position (x, y) = (261.14, 59.36), Wall Distance = 20.20 nm
# Iteration 32400: Position (x, y) = (261.13, 59.28), Wall Distance = 20.20 nm
# Iteration 32500: Position (x, y) = (261.12, 59.19), Wall Distance = 20.20 nm
# Iteration 32600: Position (x, y) = (261.11, 59.10), Wall Distance = 20.20 nm
# Iteration 32700: Position (x, y) = (261.10, 59.01), Wall Distance = 20.20 nm
# Iteration 32800: Position (x, y) = (261.08, 58.92), Wall Distance = 20.20 nm
# Iteration 32900: Position (x, y) = (261.07, 58.83), Wall Distance = 20.20 nm
# Iteration 33000: Position (x, y) = (261.06, 58.74), Wall Distance = 20.20 nm
# Iteration 33100: Position (x, y) = (261.05, 58.65), Wall Distance = 20.20 nm
# Iteration 33200: Position (x, y) = (261.03, 58.56), Wall Distance = 20.20 nm
# Iteration 33300: Position (x, y) = (261.02, 58.47), Wall Distance = 20.20 nm
# Iteration 33400: Position (x, y) = (261.01, 58.37), Wall Distance = 20.20 nm
# Iteration 33500: Position (x, y) = (261.00, 58.28), Wall Distance = 20.20 nm
# Iteration 33600: Position (x, y) = (260.98, 58.18), Wall Distance = 20.20 nm
# Iteration 33700: Position (x, y) = (260.97, 58.09), Wall Distance = 20.20 nm
# Iteration 33800: Position (x, y) = (260.96, 57.99), Wall Distance = 20.20 nm
# Iteration 33900: Position (x, y) = (260.95, 57.89), Wall Distance = 20.20 nm
# Iteration 34000: Position (x, y) = (260.93, 57.80), Wall Distance = 20.20 nm
# Iteration 34100: Position (x, y) = (260.92, 57.70), Wall Distance = 20.20 nm
# Iteration 34200: Position (x, y) = (260.91, 57.60), Wall Distance = 20.20 nm
# Iteration 34300: Position (x, y) = (260.90, 57.50), Wall Distance = 20.20 nm
# Iteration 34400: Position (x, y) = (260.88, 57.40), Wall Distance = 20.20 nm
# Iteration 34500: Position (x, y) = (260.87, 57.30), Wall Distance = 20.20 nm
# Iteration 34600: Position (x, y) = (260.86, 57.19), Wall Distance = 20.20 nm
# Iteration 34700: Position (x, y) = (260.85, 57.09), Wall Distance = 20.20 nm
# Iteration 34800: Position (x, y) = (260.83, 56.99), Wall Distance = 20.20 nm
# Iteration 34900: Position (x, y) = (260.82, 56.88), Wall Distance = 20.20 nm
# Iteration 35000: Position (x, y) = (260.81, 56.78), Wall Distance = 20.20 nm
# Iteration 35100: Position (x, y) = (260.80, 56.67), Wall Distance = 20.20 nm
# Iteration 35200: Position (x, y) = (260.78, 56.57), Wall Distance = 20.20 nm
# Iteration 35300: Position (x, y) = (260.77, 56.46), Wall Distance = 20.20 nm
# Iteration 35400: Position (x, y) = (260.76, 56.35), Wall Distance = 20.20 nm
# Iteration 35500: Position (x, y) = (260.74, 56.24), Wall Distance = 20.20 nm
# Iteration 35600: Position (x, y) = (260.73, 56.13), Wall Distance = 20.20 nm
# Iteration 35700: Position (x, y) = (260.72, 56.02), Wall Distance = 20.20 nm
# Iteration 35800: Position (x, y) = (260.71, 55.91), Wall Distance = 20.20 nm
# Iteration 35900: Position (x, y) = (260.69, 55.80), Wall Distance = 20.20 nm
# Iteration 36000: Position (x, y) = (260.68, 55.68), Wall Distance = 20.20 nm
# Iteration 36100: Position (x, y) = (260.67, 55.57), Wall Distance = 20.20 nm
# Iteration 36200: Position (x, y) = (260.66, 55.46), Wall Distance = 20.20 nm
# Iteration 36300: Position (x, y) = (260.64, 55.34), Wall Distance = 20.20 nm
# Iteration 36400: Position (x, y) = (260.63, 55.23), Wall Distance = 20.20 nm
# Iteration 36500: Position (x, y) = (260.62, 55.11), Wall Distance = 20.20 nm
# Iteration 36600: Position (x, y) = (260.60, 54.99), Wall Distance = 20.20 nm
# Iteration 36700: Position (x, y) = (260.59, 54.87), Wall Distance = 20.20 nm
# Iteration 36800: Position (x, y) = (260.58, 54.75), Wall Distance = 20.20 nm
# Iteration 36900: Position (x, y) = (260.57, 54.64), Wall Distance = 20.20 nm
# Iteration 37000: Position (x, y) = (260.55, 54.51), Wall Distance = 20.20 nm
# Iteration 37100: Position (x, y) = (260.54, 54.39), Wall Distance = 20.20 nm
# Iteration 37200: Position (x, y) = (260.53, 54.27), Wall Distance = 20.20 nm
# Iteration 37300: Position (x, y) = (260.52, 54.15), Wall Distance = 20.20 nm
# Iteration 37400: Position (x, y) = (260.50, 54.02), Wall Distance = 20.20 nm
# Iteration 37500: Position (x, y) = (260.49, 53.90), Wall Distance = 20.20 nm
# Iteration 37600: Position (x, y) = (260.48, 53.77), Wall Distance = 20.20 nm
# Iteration 37700: Position (x, y) = (260.47, 53.65), Wall Distance = 20.20 nm
# Iteration 37800: Position (x, y) = (260.45, 53.52), Wall Distance = 20.20 nm
# Iteration 37900: Position (x, y) = (260.44, 53.39), Wall Distance = 20.20 nm
# Iteration 38000: Position (x, y) = (260.43, 53.27), Wall Distance = 20.20 nm
# Iteration 38100: Position (x, y) = (260.42, 53.14), Wall Distance = 20.20 nm
# Iteration 38200: Position (x, y) = (260.40, 53.01), Wall Distance = 20.20 nm
# Iteration 38300: Position (x, y) = (260.39, 52.88), Wall Distance = 20.20 nm
# Iteration 38400: Position (x, y) = (260.38, 52.74), Wall Distance = 20.20 nm
# Iteration 38500: Position (x, y) = (260.37, 52.61), Wall Distance = 20.20 nm
# Iteration 38600: Position (x, y) = (260.36, 52.48), Wall Distance = 20.20 nm
# Iteration 38700: Position (x, y) = (260.35, 52.35), Wall Distance = 20.20 nm
# Iteration 38800: Position (x, y) = (260.33, 52.21), Wall Distance = 20.20 nm
# Iteration 38900: Position (x, y) = (260.32, 52.08), Wall Distance = 20.20 nm
# Iteration 39000: Position (x, y) = (260.31, 51.94), Wall Distance = 20.20 nm
# Iteration 39100: Position (x, y) = (260.30, 51.80), Wall Distance = 20.20 nm
# Iteration 39200: Position (x, y) = (260.29, 51.66), Wall Distance = 20.20 nm
# Iteration 39300: Position (x, y) = (260.28, 51.53), Wall Distance = 20.20 nm
# Iteration 39400: Position (x, y) = (260.26, 51.39), Wall Distance = 20.20 nm
# Iteration 39500: Position (x, y) = (260.25, 51.25), Wall Distance = 20.20 nm
# Iteration 39600: Position (x, y) = (260.24, 51.11), Wall Distance = 20.20 nm
# Iteration 39700: Position (x, y) = (260.23, 50.96), Wall Distance = 20.20 nm
# Iteration 39800: Position (x, y) = (260.22, 50.82), Wall Distance = 20.20 nm
# Iteration 39900: Position (x, y) = (260.21, 50.68), Wall Distance = 20.20 nm
# Iteration 40000: Position (x, y) = (260.20, 50.53), Wall Distance = 20.20 nm
# Iteration 40100: Position (x, y) = (260.19, 50.39), Wall Distance = 20.20 nm
# Iteration 40200: Position (x, y) = (260.18, 50.24), Wall Distance = 20.20 nm
# Iteration 40300: Position (x, y) = (260.17, 50.10), Wall Distance = 20.20 nm
# Iteration 40400: Position (x, y) = (260.15, 49.95), Wall Distance = 20.20 nm
# Iteration 40500: Position (x, y) = (260.14, 49.80), Wall Distance = 20.20 nm
# Iteration 40600: Position (x, y) = (260.13, 49.65), Wall Distance = 20.20 nm
# Iteration 40700: Position (x, y) = (260.12, 49.50), Wall Distance = 20.20 nm
# Iteration 40800: Position (x, y) = (260.11, 49.35), Wall Distance = 20.20 nm
# Iteration 40900: Position (x, y) = (260.10, 49.20), Wall Distance = 20.20 nm
# Iteration 41000: Position (x, y) = (260.09, 49.05), Wall Distance = 20.20 nm
# Iteration 41100: Position (x, y) = (260.08, 48.90), Wall Distance = 20.20 nm
# Iteration 41200: Position (x, y) = (260.07, 48.75), Wall Distance = 20.20 nm
# Iteration 41300: Position (x, y) = (260.06, 48.59), Wall Distance = 20.20 nm
# Iteration 41400: Position (x, y) = (260.05, 48.44), Wall Distance = 20.20 nm
# Iteration 41500: Position (x, y) = (260.05, 48.28), Wall Distance = 20.20 nm
# Iteration 41600: Position (x, y) = (260.04, 48.12), Wall Distance = 20.20 nm
# Iteration 41700: Position (x, y) = (260.03, 47.97), Wall Distance = 20.20 nm
# Iteration 41800: Position (x, y) = (260.02, 47.81), Wall Distance = 20.20 nm
# Iteration 41900: Position (x, y) = (260.01, 47.65), Wall Distance = 20.20 nm
# Iteration 42000: Position (x, y) = (260.00, 47.49), Wall Distance = 20.20 nm
# Iteration 42100: Position (x, y) = (259.99, 47.33), Wall Distance = 20.20 nm
# Iteration 42200: Position (x, y) = (259.98, 47.17), Wall Distance = 20.20 nm
# Iteration 42300: Position (x, y) = (259.98, 47.01), Wall Distance = 20.20 nm
# Iteration 42400: Position (x, y) = (259.97, 46.85), Wall Distance = 20.20 nm
# Iteration 42500: Position (x, y) = (259.96, 46.69), Wall Distance = 20.20 nm
# Iteration 42600: Position (x, y) = (259.95, 46.52), Wall Distance = 20.20 nm
# Iteration 42700: Position (x, y) = (259.94, 46.36), Wall Distance = 20.20 nm
# Iteration 42800: Position (x, y) = (259.94, 46.19), Wall Distance = 20.20 nm
# Iteration 42900: Position (x, y) = (259.93, 46.03), Wall Distance = 20.20 nm
# Iteration 43000: Position (x, y) = (259.92, 45.86), Wall Distance = 20.20 nm
# Iteration 43100: Position (x, y) = (259.92, 45.69), Wall Distance = 20.20 nm
# Iteration 43200: Position (x, y) = (259.91, 45.53), Wall Distance = 20.20 nm
# Iteration 43300: Position (x, y) = (259.90, 45.36), Wall Distance = 20.20 nm
# Iteration 43400: Position (x, y) = (259.90, 45.19), Wall Distance = 20.20 nm
# Iteration 43500: Position (x, y) = (259.89, 45.02), Wall Distance = 20.20 nm
# Iteration 43600: Position (x, y) = (259.88, 44.85), Wall Distance = 20.20 nm
# Iteration 43700: Position (x, y) = (259.88, 44.68), Wall Distance = 20.20 nm
# Iteration 43800: Position (x, y) = (259.87, 44.50), Wall Distance = 20.20 nm
# Iteration 43900: Position (x, y) = (259.87, 44.33), Wall Distance = 20.20 nm
# Iteration 44000: Position (x, y) = (259.86, 44.16), Wall Distance = 20.20 nm
# Iteration 44100: Position (x, y) = (259.86, 43.98), Wall Distance = 20.20 nm
# Iteration 44200: Position (x, y) = (259.85, 43.81), Wall Distance = 20.20 nm
# Iteration 44300: Position (x, y) = (259.85, 43.63), Wall Distance = 20.20 nm
# Iteration 44400: Position (x, y) = (259.84, 43.46), Wall Distance = 20.20 nm
# Iteration 44500: Position (x, y) = (259.84, 43.28), Wall Distance = 20.20 nm
# Iteration 44600: Position (x, y) = (259.83, 43.10), Wall Distance = 20.20 nm
# Iteration 44700: Position (x, y) = (259.83, 42.93), Wall Distance = 20.20 nm
# Iteration 44800: Position (x, y) = (259.83, 42.75), Wall Distance = 20.20 nm
# Iteration 44900: Position (x, y) = (259.82, 42.57), Wall Distance = 20.20 nm
# Iteration 45000: Position (x, y) = (259.82, 42.39), Wall Distance = 20.20 nm
# Iteration 45100: Position (x, y) = (259.82, 42.21), Wall Distance = 20.20 nm
# Iteration 45200: Position (x, y) = (259.82, 42.03), Wall Distance = 20.20 nm
# Iteration 45300: Position (x, y) = (259.81, 41.85), Wall Distance = 20.20 nm
# Iteration 45400: Position (x, y) = (259.81, 41.66), Wall Distance = 20.20 nm
# Iteration 45500: Position (x, y) = (259.81, 41.48), Wall Distance = 20.20 nm
# Iteration 45600: Position (x, y) = (259.81, 41.30), Wall Distance = 20.20 nm
# Iteration 45700: Position (x, y) = (259.81, 41.11), Wall Distance = 20.20 nm
# Iteration 45800: Position (x, y) = (259.80, 40.93), Wall Distance = 20.20 nm
# Iteration 45900: Position (x, y) = (259.80, 40.74), Wall Distance = 20.20 nm
# Iteration 46000: Position (x, y) = (259.80, 40.56), Wall Distance = 20.20 nm
# Iteration 46100: Position (x, y) = (259.80, 40.37), Wall Distance = 20.20 nm
# Iteration 46200: Position (x, y) = (259.80, 40.18), Wall Distance = 20.20 nm
# Iteration 46300: Position (x, y) = (259.80, 40.00), Wall Distance = 20.20 nm
# Iteration 46400: Position (x, y) = (259.80, 39.81), Wall Distance = 20.20 nm
# Iteration 46500: Position (x, y) = (259.80, 39.62), Wall Distance = 20.20 nm
# Iteration 46600: Position (x, y) = (259.80, 39.43), Wall Distance = 20.20 nm
# Iteration 46700: Position (x, y) = (259.80, 39.24), Wall Distance = 20.20 nm
# Iteration 46800: Position (x, y) = (259.80, 39.05), Wall Distance = 20.20 nm
# Iteration 46900: Position (x, y) = (259.81, 38.86), Wall Distance = 20.20 nm
# Iteration 47000: Position (x, y) = (259.81, 38.67), Wall Distance = 20.20 nm
# Iteration 47100: Position (x, y) = (259.81, 38.48), Wall Distance = 20.20 nm
# Iteration 47200: Position (x, y) = (259.81, 38.28), Wall Distance = 20.20 nm
# Iteration 47300: Position (x, y) = (259.81, 38.09), Wall Distance = 20.20 nm
# Iteration 47400: Position (x, y) = (259.82, 37.90), Wall Distance = 20.20 nm
# Iteration 47500: Position (x, y) = (259.82, 37.70), Wall Distance = 20.20 nm
# Iteration 47600: Position (x, y) = (259.82, 37.51), Wall Distance = 20.20 nm
# Iteration 47700: Position (x, y) = (259.83, 37.31), Wall Distance = 20.20 nm
# Iteration 47800: Position (x, y) = (259.83, 37.12), Wall Distance = 20.20 nm
# Iteration 47900: Position (x, y) = (259.83, 36.92), Wall Distance = 20.20 nm
# Iteration 48000: Position (x, y) = (259.84, 36.72), Wall Distance = 20.20 nm
# Iteration 48100: Position (x, y) = (259.84, 36.53), Wall Distance = 20.20 nm
# Iteration 48200: Position (x, y) = (259.85, 36.33), Wall Distance = 20.20 nm
# Iteration 48300: Position (x, y) = (259.85, 36.13), Wall Distance = 20.20 nm
# Iteration 48400: Position (x, y) = (259.86, 35.93), Wall Distance = 20.20 nm
# Iteration 48500: Position (x, y) = (259.87, 35.73), Wall Distance = 20.20 nm
# Iteration 48600: Position (x, y) = (259.87, 35.53), Wall Distance = 20.20 nm
# Iteration 48700: Position (x, y) = (259.88, 35.33), Wall Distance = 20.20 nm
# Iteration 48800: Position (x, y) = (259.88, 35.13), Wall Distance = 20.20 nm
# Iteration 48900: Position (x, y) = (259.89, 34.93), Wall Distance = 20.20 nm
# Iteration 49000: Position (x, y) = (259.90, 34.73), Wall Distance = 20.20 nm
# Iteration 49100: Position (x, y) = (259.91, 34.53), Wall Distance = 20.20 nm
# Iteration 49200: Position (x, y) = (259.92, 34.33), Wall Distance = 20.20 nm
# Iteration 49300: Position (x, y) = (259.92, 34.13), Wall Distance = 20.20 nm
# Iteration 49400: Position (x, y) = (259.93, 33.92), Wall Distance = 20.20 nm
# Iteration 49500: Position (x, y) = (259.94, 33.72), Wall Distance = 20.20 nm
# Iteration 49600: Position (x, y) = (259.95, 33.52), Wall Distance = 20.20 nm
# Iteration 49700: Position (x, y) = (259.96, 33.31), Wall Distance = 20.20 nm
# Iteration 49800: Position (x, y) = (259.97, 33.11), Wall Distance = 20.20 nm
# Iteration 49900: Position (x, y) = (259.98, 32.90), Wall Distance = 20.20 nm
# Iteration 50000: Position (x, y) = (259.99, 32.70), Wall Distance = 20.20 nm
# Iteration 50100: Position (x, y) = (260.00, 32.49), Wall Distance = 20.20 nm
# Iteration 50200: Position (x, y) = (260.01, 32.28), Wall Distance = 20.20 nm
# Iteration 50300: Position (x, y) = (260.02, 32.08), Wall Distance = 20.20 nm
# Iteration 50400: Position (x, y) = (260.04, 31.87), Wall Distance = 20.20 nm
# Iteration 50500: Position (x, y) = (260.05, 31.66), Wall Distance = 20.20 nm
# Iteration 50600: Position (x, y) = (260.06, 31.46), Wall Distance = 20.20 nm
# Iteration 50700: Position (x, y) = (260.07, 31.25), Wall Distance = 20.20 nm
# Iteration 50800: Position (x, y) = (260.09, 31.04), Wall Distance = 20.20 nm
# Iteration 50900: Position (x, y) = (260.10, 30.83), Wall Distance = 20.20 nm
# Iteration 51000: Position (x, y) = (260.11, 30.62), Wall Distance = 20.20 nm
# Iteration 51100: Position (x, y) = (260.13, 30.41), Wall Distance = 20.20 nm
# Iteration 51200: Position (x, y) = (260.14, 30.20), Wall Distance = 20.20 nm
# Iteration 51300: Position (x, y) = (260.16, 29.99), Wall Distance = 20.20 nm
# Iteration 51400: Position (x, y) = (260.17, 29.78), Wall Distance = 20.20 nm
# Iteration 51500: Position (x, y) = (260.19, 29.57), Wall Distance = 20.20 nm
# Iteration 51600: Position (x, y) = (260.21, 29.36), Wall Distance = 20.20 nm
# Iteration 51700: Position (x, y) = (260.22, 29.14), Wall Distance = 20.20 nm
# Iteration 51800: Position (x, y) = (260.24, 28.93), Wall Distance = 20.20 nm
# Iteration 51900: Position (x, y) = (260.25, 28.72), Wall Distance = 20.20 nm
# Iteration 52000: Position (x, y) = (260.27, 28.51), Wall Distance = 20.20 nm
# Iteration 52100: Position (x, y) = (260.29, 28.29), Wall Distance = 20.20 nm
# Iteration 52200: Position (x, y) = (260.31, 28.08), Wall Distance = 20.20 nm
# Iteration 52300: Position (x, y) = (260.33, 27.87), Wall Distance = 20.20 nm
# Iteration 52400: Position (x, y) = (260.35, 27.65), Wall Distance = 20.20 nm
# Iteration 52500: Position (x, y) = (260.37, 27.42), Wall Distance = 20.20 nm
# Iteration 52600: Position (x, y) = (260.39, 27.17), Wall Distance = 20.20 nm
# Iteration 52700: Position (x, y) = (260.41, 26.92), Wall Distance = 20.20 nm
# Iteration 52800: Position (x, y) = (260.44, 26.67), Wall Distance = 20.20 nm
# Iteration 52900: Position (x, y) = (260.46, 26.42), Wall Distance = 20.20 nm
# Iteration 53000: Position (x, y) = (260.49, 26.17), Wall Distance = 20.20 nm
# Total simulation time: 56.42 seconds

# %%
#i believe it got the thing right
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import LinearNDInterpolator, griddata
import pandas as pd
import time

# Define the centers and radius of the circular posts
centers = [(0, 0), (0, 400), (400, 40), (400, 440)]
radius = 120  # radius of pillar nanometers
radius_of_particle = 20.5
y_s = radius + radius_of_particle
wall_distance_threshold = radius_of_particle  # Set the wall distance threshold as a variable


# Create a grid to compute distances
x_range = np.linspace(0, 400, 400)
y_range = np.linspace(0, 440, 400)
X, Y = np.meshgrid(x_range, y_range)

# Calculate the distance from each point in the grid to the nearest circular post
distances = np.full_like(X, np.inf, dtype=float)  # initialize with infinity

for cx, cy in centers:
    distance_to_post = np.sqrt((X - cx)**2 + (Y - cy)**2) - radius
    distances = np.minimum(distances, distance_to_post)  # take the minimum distance

# Set negative distances to zero
distances = np.maximum(distances, 0)

# Calculate the gradient of the wall distance function
dy, dx = np.gradient(distances, y_range, x_range)

# Calculate the magnitude of the gradient (surface normal)
gradient_magnitude = np.sqrt(dx**2 + dy**2)

# Initialize normal_x and normal_y with zeros
normal_x = np.zeros_like(dx)
normal_y = np.zeros_like(dy)

# Avoid division by zero by normalizing only where gradient_magnitude is not zero
non_zero_magnitude = gradient_magnitude > 0
normal_x[non_zero_magnitude] = dx[non_zero_magnitude] / gradient_magnitude[non_zero_magnitude]
normal_y[non_zero_magnitude] = dy[non_zero_magnitude] / gradient_magnitude[non_zero_magnitude]

# Create LinearNDInterpolators for wall distance and normals
wall_distance_interp = LinearNDInterpolator(list(zip(X.ravel(), Y.ravel())), distances.ravel(), fill_value=np.inf)
normal_x_interp = LinearNDInterpolator(list(zip(X.ravel(), Y.ravel())), normal_x.ravel(), fill_value=0)
normal_y_interp = LinearNDInterpolator(list(zip(X.ravel(), Y.ravel())), normal_y.ravel(), fill_value=0)

# Load the particle velocity data
file_path = r"C:\Users\mahir\OneDrive\Desktop\CustomM_0.24.csv"
velocity_field_data = pd.read_csv(file_path)

x = velocity_field_data['x'].values
y = velocity_field_data['y'].values
u = velocity_field_data['u1x (m/s) @ t=0.01'].values
v = velocity_field_data['u1y (m/s) @ t=0.01'].values

# Normalize the velocity components
maxu = np.max(np.abs(u))
maxv = np.max(np.abs(v))
max_vel = max(maxu, maxv)

# Create LinearNDInterpolator for U and V fields
u_interp = LinearNDInterpolator(list(zip(x, y)), u / max_vel)  # Normalize during interpolation setup
v_interp = LinearNDInterpolator(list(zip(x, y)), v / max_vel)

def velocity(x, y, u_interp, v_interp):
    """Interpolate velocity at the particle's position."""
    u = u_interp(x, y)
    v = v_interp(x, y)
    return u, v

def rk4_step(x, y, dt, u, v):
    """Calculate the next position of the particle using RK4 with provided velocity components."""
    # k1
    k1x = dt * u
    k1y = dt * v

    # k2
    u2, v2 = velocity(x + k1x / 2, y + k1y / 2, u_interp, v_interp)
    k2x = dt * u2
    k2y = dt * v2

    # k3
    u3, v3 = velocity(x + k2x / 2, y + k2y / 2, u_interp, v_interp)
    k3x = dt * u3
    k3y = dt * v3

    # k4
    u4, v4 = velocity(x + k3x, y + k3y, u_interp, v_interp)
    k4x = dt * u4
    k4y = dt * v4

    # Combine increments to get the next position
    x_next = x + (k1x + 2 * k2x + 2 * k3x + k4x) / 6
    y_next = y + (k1y + 2 * k2y + 2 * k3y + k4y) / 6

    return x_next, y_next

# Initial position of the particle
x0, y0 = 0, y_s  # Starting at x=0, y=142.5
dt = 0.1  # Time step

# Lists to store the particle's trajectory and wall distance
x_traj = [x0]
y_traj = [y0]
wall_distances = []  # To store the wall distance after each iteration

# Start timer for simulation
start_time = time.time()

# Initialize the initial velocity
#u, v = velocity(x0, y0, u_interp, v_interp)
u, v = 0, 0
print(f" v = {v:.5f}")

# Simulate the particle trajectory with COMSOL-like reflection mode
i = 0
while x_traj[-1] < 399.99 and y_traj[-1] > 0.01:
    x_next, y_next = rk4_step(x_traj[-1], y_traj[-1], dt, u, v)
    
    # Interpolate wall distance at the new position
    distance_to_wall = wall_distance_interp(x_next, y_next)
    wall_distances.append(distance_to_wall)  # Append the wall distance to the list
    
    # Check if particle hits the wall (distance <= wall_distance_threshold)
    if distance_to_wall <= wall_distance_threshold:
        # Get the normal vector at the point of collision
        nx = normal_x_interp(x_next, y_next)
        ny = normal_y_interp(x_next, y_next)
        
        # Reflect the velocity according to the COMSOL-style bounce model
        # Calculate the incident angle and reflect the velocity across the normal
        dot_product = u * nx + v * ny
        u = u - 2 * dot_product * nx
        v = v - 2 * dot_product * ny
        
        # Move the particle to exactly wall_distance_threshold away from the wall along the normal direction
        x_next = x_next + (wall_distance_threshold - distance_to_wall) * nx
        y_next = y_next + (wall_distance_threshold - distance_to_wall) * ny
        
        # Update distance to ensure it's precisely at the threshold after moving
        distance_to_wall = wall_distance_interp(x_next, y_next)
    else:
        u, v = velocity(x_next, y_next, u_interp, v_interp)
        
    if x_next > 399.5:
        print(f"Iteration {i}: Position (x, y) = ({x_next:.2f}, {y_next:.2f}), u = {u:.5f}, v = {v:.5f} ")

    
    # Append the updated position after reflection if necessary
    x_traj.append(x_next)
    y_traj.append(y_next)

    # Print position and wall distance every 100 iterations
    i += 1
    if i % 100 == 0:
        print(f"Iteration {i}: Position (x, y) = ({x_next:.2f}, {y_next:.2f}), Wall Distance = {distance_to_wall:.2f} nm")

# End timer for simulation
end_time = time.time()
total_time = end_time - start_time
print(f"Total simulation time: {total_time:.2f} seconds")

# Plot the results
plt.figure(figsize=(10, 8))
plt.contourf(X, Y, distances, levels=50, cmap='coolwarm')
plt.colorbar(label='Distance to Wall (nm)')
plt.plot(x_traj, y_traj, 'r-', label='Particle Trajectory')
plt.scatter([x0], [y0], color='red', label='Start Position')
plt.xlabel('X Position (nm)')
plt.ylabel('Y Position (nm)')
plt.legend()
plt.title('Particle Trajectory with COMSOL-Style Reflection Mode')
plt.show()
# Out:
#  v = 0.00000
# Iteration 100: Position (x, y) = (5.06, 140.44), Wall Distance = 20.53 nm
# Iteration 200: Position (x, y) = (10.10, 140.27), Wall Distance = 20.63 nm
# Iteration 300: Position (x, y) = (15.11, 139.97), Wall Distance = 20.79 nm
# Iteration 400: Position (x, y) = (20.07, 139.56), Wall Distance = 21.00 nm
# Iteration 500: Position (x, y) = (24.97, 139.04), Wall Distance = 21.27 nm
# Iteration 600: Position (x, y) = (29.79, 138.42), Wall Distance = 21.59 nm
# Iteration 700: Position (x, y) = (34.52, 137.69), Wall Distance = 21.96 nm
# Iteration 800: Position (x, y) = (39.16, 136.88), Wall Distance = 22.37 nm
# Iteration 900: Position (x, y) = (43.69, 135.98), Wall Distance = 22.83 nm
# Iteration 1000: Position (x, y) = (48.11, 135.02), Wall Distance = 23.33 nm
# Iteration 1100: Position (x, y) = (52.42, 133.99), Wall Distance = 23.88 nm
# Iteration 1200: Position (x, y) = (56.62, 132.90), Wall Distance = 24.46 nm
# Iteration 1300: Position (x, y) = (60.70, 131.77), Wall Distance = 25.08 nm
# Iteration 1400: Position (x, y) = (64.66, 130.60), Wall Distance = 25.73 nm
# Iteration 1500: Position (x, y) = (68.51, 129.40), Wall Distance = 26.42 nm
# Iteration 1600: Position (x, y) = (72.25, 128.18), Wall Distance = 27.14 nm
# Iteration 1700: Position (x, y) = (75.88, 126.94), Wall Distance = 27.89 nm
# Iteration 1800: Position (x, y) = (79.40, 125.69), Wall Distance = 28.67 nm
# Iteration 1900: Position (x, y) = (82.82, 124.44), Wall Distance = 29.48 nm
# Iteration 2000: Position (x, y) = (86.14, 123.18), Wall Distance = 30.31 nm
# Iteration 2100: Position (x, y) = (89.37, 121.93), Wall Distance = 31.17 nm
# Iteration 2200: Position (x, y) = (92.50, 120.69), Wall Distance = 32.06 nm
# Iteration 2300: Position (x, y) = (95.55, 119.45), Wall Distance = 32.97 nm
# Iteration 2400: Position (x, y) = (98.52, 118.23), Wall Distance = 33.90 nm
# Iteration 2500: Position (x, y) = (101.41, 117.03), Wall Distance = 34.85 nm
# Iteration 2600: Position (x, y) = (104.23, 115.84), Wall Distance = 35.83 nm
# Iteration 2700: Position (x, y) = (106.97, 114.67), Wall Distance = 36.82 nm
# Iteration 2800: Position (x, y) = (109.65, 113.52), Wall Distance = 37.83 nm
# Iteration 2900: Position (x, y) = (112.27, 112.39), Wall Distance = 38.86 nm
# Iteration 3000: Position (x, y) = (114.83, 111.28), Wall Distance = 39.90 nm
# Iteration 3100: Position (x, y) = (117.32, 110.20), Wall Distance = 40.96 nm
# Iteration 3200: Position (x, y) = (119.77, 109.14), Wall Distance = 42.04 nm
# Iteration 3300: Position (x, y) = (122.16, 108.10), Wall Distance = 43.12 nm
# Iteration 3400: Position (x, y) = (124.51, 107.08), Wall Distance = 44.22 nm
# Iteration 3500: Position (x, y) = (126.80, 106.08), Wall Distance = 45.33 nm
# Iteration 3600: Position (x, y) = (129.06, 105.11), Wall Distance = 46.45 nm
# Iteration 3700: Position (x, y) = (131.27, 104.16), Wall Distance = 47.57 nm
# Iteration 3800: Position (x, y) = (133.43, 103.24), Wall Distance = 48.71 nm
# Iteration 3900: Position (x, y) = (135.56, 102.33), Wall Distance = 49.85 nm
# Iteration 4000: Position (x, y) = (137.65, 101.45), Wall Distance = 51.00 nm
# Iteration 4100: Position (x, y) = (139.70, 100.59), Wall Distance = 52.15 nm
# Iteration 4200: Position (x, y) = (141.72, 99.75), Wall Distance = 53.31 nm
# Iteration 4300: Position (x, y) = (143.70, 98.93), Wall Distance = 54.47 nm
# Iteration 4400: Position (x, y) = (145.65, 98.13), Wall Distance = 55.63 nm
# Iteration 4500: Position (x, y) = (147.57, 97.35), Wall Distance = 56.79 nm
# Iteration 4600: Position (x, y) = (149.46, 96.59), Wall Distance = 57.95 nm
# Iteration 4700: Position (x, y) = (151.31, 95.85), Wall Distance = 59.11 nm
# Iteration 4800: Position (x, y) = (153.14, 95.13), Wall Distance = 60.28 nm
# Iteration 4900: Position (x, y) = (154.93, 94.42), Wall Distance = 61.44 nm
# Iteration 5000: Position (x, y) = (156.70, 93.73), Wall Distance = 62.59 nm
# Iteration 5100: Position (x, y) = (158.44, 93.06), Wall Distance = 63.75 nm
# Iteration 5200: Position (x, y) = (160.15, 92.41), Wall Distance = 64.90 nm
# Iteration 5300: Position (x, y) = (161.84, 91.77), Wall Distance = 66.05 nm
# Iteration 5400: Position (x, y) = (163.50, 91.15), Wall Distance = 67.19 nm
# Iteration 5500: Position (x, y) = (165.13, 90.55), Wall Distance = 68.33 nm
# Iteration 5600: Position (x, y) = (166.74, 89.96), Wall Distance = 69.46 nm
# Iteration 5700: Position (x, y) = (168.32, 89.39), Wall Distance = 70.59 nm
# Iteration 5800: Position (x, y) = (169.88, 88.82), Wall Distance = 71.71 nm
# Iteration 5900: Position (x, y) = (171.42, 88.28), Wall Distance = 72.82 nm
# Iteration 6000: Position (x, y) = (172.93, 87.75), Wall Distance = 73.92 nm
# Iteration 6100: Position (x, y) = (174.42, 87.23), Wall Distance = 75.02 nm
# Iteration 6200: Position (x, y) = (175.89, 86.73), Wall Distance = 76.11 nm
# Iteration 6300: Position (x, y) = (177.33, 86.23), Wall Distance = 77.19 nm
# Iteration 6400: Position (x, y) = (178.75, 85.75), Wall Distance = 78.26 nm
# Iteration 6500: Position (x, y) = (180.16, 85.29), Wall Distance = 79.32 nm
# Iteration 6600: Position (x, y) = (181.53, 84.83), Wall Distance = 80.38 nm
# Iteration 6700: Position (x, y) = (182.89, 84.39), Wall Distance = 81.42 nm
# Iteration 6800: Position (x, y) = (184.23, 83.96), Wall Distance = 82.46 nm
# Iteration 6900: Position (x, y) = (185.54, 83.54), Wall Distance = 83.48 nm
# Iteration 7000: Position (x, y) = (186.84, 83.13), Wall Distance = 84.50 nm
# Iteration 7100: Position (x, y) = (188.12, 82.73), Wall Distance = 85.50 nm
# Iteration 7200: Position (x, y) = (189.37, 82.34), Wall Distance = 86.50 nm
# Iteration 7300: Position (x, y) = (190.61, 81.96), Wall Distance = 87.48 nm
# Iteration 7400: Position (x, y) = (191.82, 81.59), Wall Distance = 88.45 nm
# Iteration 7500: Position (x, y) = (193.02, 81.23), Wall Distance = 89.42 nm
# Iteration 7600: Position (x, y) = (194.20, 80.88), Wall Distance = 89.63 nm
# Iteration 7700: Position (x, y) = (195.37, 80.54), Wall Distance = 88.61 nm
# Iteration 7800: Position (x, y) = (196.51, 80.20), Wall Distance = 87.42 nm
# Iteration 7900: Position (x, y) = (197.64, 79.88), Wall Distance = 86.25 nm
# Iteration 8000: Position (x, y) = (198.75, 79.56), Wall Distance = 85.11 nm
# Iteration 8100: Position (x, y) = (199.84, 79.25), Wall Distance = 83.98 nm
# Iteration 8200: Position (x, y) = (200.91, 78.95), Wall Distance = 82.87 nm
# Iteration 8300: Position (x, y) = (201.97, 78.66), Wall Distance = 81.77 nm
# Iteration 8400: Position (x, y) = (203.01, 78.38), Wall Distance = 80.70 nm
# Iteration 8500: Position (x, y) = (204.03, 78.10), Wall Distance = 79.64 nm
# Iteration 8600: Position (x, y) = (205.04, 77.83), Wall Distance = 78.60 nm
# Iteration 8700: Position (x, y) = (206.03, 77.56), Wall Distance = 77.57 nm
# Iteration 8800: Position (x, y) = (207.01, 77.31), Wall Distance = 76.56 nm
# Iteration 8900: Position (x, y) = (207.97, 77.06), Wall Distance = 75.57 nm
# Iteration 9000: Position (x, y) = (208.92, 76.81), Wall Distance = 74.60 nm
# Iteration 9100: Position (x, y) = (209.85, 76.57), Wall Distance = 73.64 nm
# Iteration 9200: Position (x, y) = (210.76, 76.34), Wall Distance = 72.70 nm
# Iteration 9300: Position (x, y) = (211.66, 76.11), Wall Distance = 71.77 nm
# Iteration 9400: Position (x, y) = (212.55, 75.89), Wall Distance = 70.86 nm
# Iteration 9500: Position (x, y) = (213.42, 75.68), Wall Distance = 69.96 nm
# Iteration 9600: Position (x, y) = (214.28, 75.47), Wall Distance = 69.07 nm
# Iteration 9700: Position (x, y) = (215.13, 75.26), Wall Distance = 68.21 nm
# Iteration 9800: Position (x, y) = (215.96, 75.06), Wall Distance = 67.35 nm
# Iteration 9900: Position (x, y) = (216.78, 74.86), Wall Distance = 66.51 nm
# Iteration 10000: Position (x, y) = (217.58, 74.67), Wall Distance = 65.68 nm
# Iteration 10100: Position (x, y) = (218.38, 74.49), Wall Distance = 64.87 nm
# Iteration 10200: Position (x, y) = (219.16, 74.30), Wall Distance = 64.07 nm
# Iteration 10300: Position (x, y) = (219.92, 74.12), Wall Distance = 63.28 nm
# Iteration 10400: Position (x, y) = (220.68, 73.95), Wall Distance = 62.51 nm
# Iteration 10500: Position (x, y) = (221.42, 73.78), Wall Distance = 61.75 nm
# Iteration 10600: Position (x, y) = (222.15, 73.61), Wall Distance = 61.00 nm
# Iteration 10700: Position (x, y) = (222.87, 73.45), Wall Distance = 60.26 nm
# Iteration 10800: Position (x, y) = (223.58, 73.29), Wall Distance = 59.54 nm
# Iteration 10900: Position (x, y) = (224.27, 73.13), Wall Distance = 58.83 nm
# Iteration 11000: Position (x, y) = (224.96, 72.98), Wall Distance = 58.13 nm
# Iteration 11100: Position (x, y) = (225.63, 72.83), Wall Distance = 57.43 nm
# Iteration 11200: Position (x, y) = (226.29, 72.69), Wall Distance = 56.76 nm
# Iteration 11300: Position (x, y) = (226.95, 72.54), Wall Distance = 56.09 nm
# Iteration 11400: Position (x, y) = (227.59, 72.40), Wall Distance = 55.43 nm
# Iteration 11500: Position (x, y) = (228.22, 72.27), Wall Distance = 54.79 nm
# Iteration 11600: Position (x, y) = (228.84, 72.13), Wall Distance = 54.15 nm
# Iteration 11700: Position (x, y) = (229.45, 72.00), Wall Distance = 53.52 nm
# Iteration 11800: Position (x, y) = (230.05, 71.87), Wall Distance = 52.91 nm
# Iteration 11900: Position (x, y) = (230.65, 71.74), Wall Distance = 52.30 nm
# Iteration 12000: Position (x, y) = (231.23, 71.62), Wall Distance = 51.71 nm
# Iteration 12100: Position (x, y) = (231.80, 71.50), Wall Distance = 51.12 nm
# Iteration 12200: Position (x, y) = (232.37, 71.38), Wall Distance = 50.54 nm
# Iteration 12300: Position (x, y) = (232.92, 71.26), Wall Distance = 49.98 nm
# Iteration 12400: Position (x, y) = (233.47, 71.14), Wall Distance = 49.42 nm
# Iteration 12500: Position (x, y) = (234.01, 71.03), Wall Distance = 48.87 nm
# Iteration 12600: Position (x, y) = (234.53, 70.92), Wall Distance = 48.33 nm
# Iteration 12700: Position (x, y) = (235.05, 70.81), Wall Distance = 47.80 nm
# Iteration 12800: Position (x, y) = (235.57, 70.70), Wall Distance = 47.27 nm
# Iteration 12900: Position (x, y) = (236.07, 70.59), Wall Distance = 46.76 nm
# Iteration 13000: Position (x, y) = (236.56, 70.49), Wall Distance = 46.26 nm
# Iteration 13100: Position (x, y) = (237.05, 70.38), Wall Distance = 45.76 nm
# Iteration 13200: Position (x, y) = (237.53, 70.28), Wall Distance = 45.27 nm
# Iteration 13300: Position (x, y) = (238.00, 70.18), Wall Distance = 44.79 nm
# Iteration 13400: Position (x, y) = (238.46, 70.08), Wall Distance = 44.31 nm
# Iteration 13500: Position (x, y) = (238.92, 69.98), Wall Distance = 43.85 nm
# Iteration 13600: Position (x, y) = (239.37, 69.88), Wall Distance = 43.39 nm
# Iteration 13700: Position (x, y) = (239.81, 69.79), Wall Distance = 42.94 nm
# Iteration 13800: Position (x, y) = (240.25, 69.69), Wall Distance = 42.49 nm
# Iteration 13900: Position (x, y) = (240.67, 69.60), Wall Distance = 42.05 nm
# Iteration 14000: Position (x, y) = (241.09, 69.51), Wall Distance = 41.62 nm
# Iteration 14100: Position (x, y) = (241.51, 69.41), Wall Distance = 41.20 nm
# Iteration 14200: Position (x, y) = (241.92, 69.32), Wall Distance = 40.78 nm
# Iteration 14300: Position (x, y) = (242.32, 69.23), Wall Distance = 40.37 nm
# Iteration 14400: Position (x, y) = (242.71, 69.14), Wall Distance = 39.96 nm
# Iteration 14500: Position (x, y) = (243.10, 69.05), Wall Distance = 39.57 nm
# Iteration 14600: Position (x, y) = (243.48, 68.97), Wall Distance = 39.17 nm
# Iteration 14700: Position (x, y) = (243.86, 68.88), Wall Distance = 38.79 nm
# Iteration 14800: Position (x, y) = (244.23, 68.79), Wall Distance = 38.41 nm
# Iteration 14900: Position (x, y) = (244.59, 68.71), Wall Distance = 38.04 nm
# Iteration 15000: Position (x, y) = (244.95, 68.62), Wall Distance = 37.67 nm
# Iteration 15100: Position (x, y) = (245.31, 68.54), Wall Distance = 37.30 nm
# Iteration 15200: Position (x, y) = (245.65, 68.46), Wall Distance = 36.95 nm
# Iteration 15300: Position (x, y) = (246.00, 68.37), Wall Distance = 36.59 nm
# Iteration 15400: Position (x, y) = (246.33, 68.29), Wall Distance = 36.25 nm
# Iteration 15500: Position (x, y) = (246.67, 68.21), Wall Distance = 35.91 nm
# Iteration 15600: Position (x, y) = (246.99, 68.13), Wall Distance = 35.57 nm
# Iteration 15700: Position (x, y) = (247.31, 68.04), Wall Distance = 35.24 nm
# Iteration 15800: Position (x, y) = (247.63, 67.96), Wall Distance = 34.92 nm
# Iteration 15900: Position (x, y) = (247.94, 67.88), Wall Distance = 34.60 nm
# Iteration 16000: Position (x, y) = (248.24, 67.80), Wall Distance = 34.28 nm
# Iteration 16100: Position (x, y) = (248.55, 67.72), Wall Distance = 33.97 nm
# Iteration 16200: Position (x, y) = (248.84, 67.64), Wall Distance = 33.67 nm
# Iteration 16300: Position (x, y) = (249.13, 67.56), Wall Distance = 33.36 nm
# Iteration 16400: Position (x, y) = (249.42, 67.48), Wall Distance = 33.07 nm
# Iteration 16500: Position (x, y) = (249.70, 67.40), Wall Distance = 32.77 nm
# Iteration 16600: Position (x, y) = (249.98, 67.32), Wall Distance = 32.49 nm
# Iteration 16700: Position (x, y) = (250.26, 67.25), Wall Distance = 32.20 nm
# Iteration 16800: Position (x, y) = (250.53, 67.17), Wall Distance = 31.92 nm
# Iteration 16900: Position (x, y) = (250.79, 67.09), Wall Distance = 31.65 nm
# Iteration 17000: Position (x, y) = (251.05, 67.01), Wall Distance = 31.38 nm
# Iteration 17100: Position (x, y) = (251.31, 66.93), Wall Distance = 31.11 nm
# Iteration 17200: Position (x, y) = (251.56, 66.85), Wall Distance = 30.85 nm
# Iteration 17300: Position (x, y) = (251.81, 66.77), Wall Distance = 30.59 nm
# Iteration 17400: Position (x, y) = (252.06, 66.69), Wall Distance = 30.33 nm
# Iteration 17500: Position (x, y) = (252.30, 66.61), Wall Distance = 30.08 nm
# Iteration 17600: Position (x, y) = (252.54, 66.53), Wall Distance = 29.83 nm
# Iteration 17700: Position (x, y) = (252.77, 66.46), Wall Distance = 29.59 nm
# Iteration 17800: Position (x, y) = (253.00, 66.38), Wall Distance = 29.35 nm
# Iteration 17900: Position (x, y) = (253.23, 66.30), Wall Distance = 29.11 nm
# Iteration 18000: Position (x, y) = (253.45, 66.22), Wall Distance = 28.88 nm
# Iteration 18100: Position (x, y) = (253.67, 66.14), Wall Distance = 28.65 nm
# Iteration 18200: Position (x, y) = (253.89, 66.06), Wall Distance = 28.42 nm
# Iteration 18300: Position (x, y) = (254.10, 65.98), Wall Distance = 28.20 nm
# Iteration 18400: Position (x, y) = (254.31, 65.90), Wall Distance = 27.98 nm
# Iteration 18500: Position (x, y) = (254.52, 65.82), Wall Distance = 27.76 nm
# Iteration 18600: Position (x, y) = (254.72, 65.74), Wall Distance = 27.54 nm
# Iteration 18700: Position (x, y) = (254.92, 65.65), Wall Distance = 27.33 nm
# Iteration 18800: Position (x, y) = (255.12, 65.57), Wall Distance = 27.13 nm
# Iteration 18900: Position (x, y) = (255.31, 65.49), Wall Distance = 26.92 nm
# Iteration 19000: Position (x, y) = (255.50, 65.41), Wall Distance = 26.72 nm
# Iteration 19100: Position (x, y) = (255.69, 65.33), Wall Distance = 26.52 nm
# Iteration 19200: Position (x, y) = (255.87, 65.25), Wall Distance = 26.32 nm
# Iteration 19300: Position (x, y) = (256.06, 65.17), Wall Distance = 26.13 nm
# Iteration 19400: Position (x, y) = (256.24, 65.08), Wall Distance = 25.93 nm
# Iteration 19500: Position (x, y) = (256.41, 65.00), Wall Distance = 25.75 nm
# Iteration 19600: Position (x, y) = (256.59, 64.92), Wall Distance = 25.56 nm
# Iteration 19700: Position (x, y) = (256.76, 64.84), Wall Distance = 25.38 nm
# Iteration 19800: Position (x, y) = (256.93, 64.75), Wall Distance = 25.19 nm
# Iteration 19900: Position (x, y) = (257.10, 64.67), Wall Distance = 25.02 nm
# Iteration 20000: Position (x, y) = (257.26, 64.58), Wall Distance = 24.84 nm
# Iteration 20100: Position (x, y) = (257.42, 64.50), Wall Distance = 24.67 nm
# Iteration 20200: Position (x, y) = (257.58, 64.42), Wall Distance = 24.50 nm
# Iteration 20300: Position (x, y) = (257.74, 64.33), Wall Distance = 24.33 nm
# Iteration 20400: Position (x, y) = (257.89, 64.24), Wall Distance = 24.16 nm
# Iteration 20500: Position (x, y) = (258.04, 64.16), Wall Distance = 24.00 nm
# Iteration 20600: Position (x, y) = (258.19, 64.07), Wall Distance = 23.84 nm
# Iteration 20700: Position (x, y) = (258.34, 63.98), Wall Distance = 23.68 nm
# Iteration 20800: Position (x, y) = (258.48, 63.90), Wall Distance = 23.52 nm
# Iteration 20900: Position (x, y) = (258.63, 63.81), Wall Distance = 23.37 nm
# Iteration 21000: Position (x, y) = (258.77, 63.72), Wall Distance = 23.21 nm
# Iteration 21100: Position (x, y) = (258.90, 63.63), Wall Distance = 23.06 nm
# Iteration 21200: Position (x, y) = (259.04, 63.54), Wall Distance = 22.92 nm
# Iteration 21300: Position (x, y) = (259.17, 63.45), Wall Distance = 22.77 nm
# Iteration 21400: Position (x, y) = (259.30, 63.36), Wall Distance = 22.62 nm
# Iteration 21500: Position (x, y) = (259.43, 63.27), Wall Distance = 22.48 nm
# Iteration 21600: Position (x, y) = (259.56, 63.18), Wall Distance = 22.34 nm
# Iteration 21700: Position (x, y) = (259.69, 63.09), Wall Distance = 22.20 nm
# Iteration 21800: Position (x, y) = (259.81, 63.00), Wall Distance = 22.06 nm
# Iteration 21900: Position (x, y) = (259.93, 62.91), Wall Distance = 21.93 nm
# Iteration 22000: Position (x, y) = (260.05, 62.81), Wall Distance = 21.80 nm
# Iteration 22100: Position (x, y) = (260.17, 62.72), Wall Distance = 21.66 nm
# Iteration 22200: Position (x, y) = (260.29, 62.63), Wall Distance = 21.53 nm
# Iteration 22300: Position (x, y) = (260.40, 62.53), Wall Distance = 21.41 nm
# Iteration 22400: Position (x, y) = (260.51, 62.44), Wall Distance = 21.28 nm
# Iteration 22500: Position (x, y) = (260.63, 62.35), Wall Distance = 21.16 nm
# Iteration 22600: Position (x, y) = (260.74, 62.25), Wall Distance = 21.03 nm
# Iteration 22700: Position (x, y) = (260.84, 62.15), Wall Distance = 20.91 nm
# Iteration 22800: Position (x, y) = (260.95, 62.06), Wall Distance = 20.79 nm
# Iteration 22900: Position (x, y) = (261.05, 61.96), Wall Distance = 20.67 nm
# Iteration 23000: Position (x, y) = (261.16, 61.86), Wall Distance = 20.56 nm
# Iteration 23100: Position (x, y) = (261.20, 61.77), Wall Distance = 20.50 nm
# Iteration 23200: Position (x, y) = (261.19, 61.69), Wall Distance = 20.50 nm
# Iteration 23300: Position (x, y) = (261.17, 61.61), Wall Distance = 20.50 nm
# Iteration 23400: Position (x, y) = (261.16, 61.53), Wall Distance = 20.50 nm
# Iteration 23500: Position (x, y) = (261.15, 61.45), Wall Distance = 20.50 nm
# Iteration 23600: Position (x, y) = (261.13, 61.36), Wall Distance = 20.50 nm
# Iteration 23700: Position (x, y) = (261.12, 61.28), Wall Distance = 20.50 nm
# Iteration 23800: Position (x, y) = (261.11, 61.19), Wall Distance = 20.50 nm
# Iteration 23900: Position (x, y) = (261.10, 61.11), Wall Distance = 20.50 nm
# Iteration 24000: Position (x, y) = (261.08, 61.02), Wall Distance = 20.50 nm
# Iteration 24100: Position (x, y) = (261.07, 60.93), Wall Distance = 20.50 nm
# Iteration 24200: Position (x, y) = (261.06, 60.84), Wall Distance = 20.50 nm
# Iteration 24300: Position (x, y) = (261.04, 60.75), Wall Distance = 20.50 nm
# Iteration 24400: Position (x, y) = (261.03, 60.66), Wall Distance = 20.50 nm
# Iteration 24500: Position (x, y) = (261.01, 60.57), Wall Distance = 20.50 nm
# Iteration 24600: Position (x, y) = (261.00, 60.48), Wall Distance = 20.50 nm
# Iteration 24700: Position (x, y) = (260.99, 60.39), Wall Distance = 20.50 nm
# Iteration 24800: Position (x, y) = (260.97, 60.30), Wall Distance = 20.50 nm
# Iteration 24900: Position (x, y) = (260.96, 60.20), Wall Distance = 20.50 nm
# Iteration 25000: Position (x, y) = (260.95, 60.11), Wall Distance = 20.50 nm
# Iteration 25100: Position (x, y) = (260.93, 60.01), Wall Distance = 20.50 nm
# Iteration 25200: Position (x, y) = (260.92, 59.92), Wall Distance = 20.50 nm
# Iteration 25300: Position (x, y) = (260.91, 59.82), Wall Distance = 20.50 nm
# Iteration 25400: Position (x, y) = (260.89, 59.72), Wall Distance = 20.50 nm
# Iteration 25500: Position (x, y) = (260.88, 59.62), Wall Distance = 20.50 nm
# Iteration 25600: Position (x, y) = (260.86, 59.52), Wall Distance = 20.50 nm
# Iteration 25700: Position (x, y) = (260.85, 59.42), Wall Distance = 20.50 nm
# Iteration 25800: Position (x, y) = (260.84, 59.32), Wall Distance = 20.50 nm
# Iteration 25900: Position (x, y) = (260.82, 59.22), Wall Distance = 20.50 nm
# Iteration 26000: Position (x, y) = (260.81, 59.12), Wall Distance = 20.50 nm
# Iteration 26100: Position (x, y) = (260.79, 59.01), Wall Distance = 20.50 nm
# Iteration 26200: Position (x, y) = (260.78, 58.91), Wall Distance = 20.50 nm
# Iteration 26300: Position (x, y) = (260.77, 58.80), Wall Distance = 20.50 nm
# Iteration 26400: Position (x, y) = (260.75, 58.70), Wall Distance = 20.50 nm
# Iteration 26500: Position (x, y) = (260.74, 58.59), Wall Distance = 20.50 nm
# Iteration 26600: Position (x, y) = (260.72, 58.48), Wall Distance = 20.50 nm
# Iteration 26700: Position (x, y) = (260.71, 58.37), Wall Distance = 20.50 nm
# Iteration 26800: Position (x, y) = (260.69, 58.26), Wall Distance = 20.50 nm
# Iteration 26900: Position (x, y) = (260.68, 58.15), Wall Distance = 20.50 nm
# Iteration 27000: Position (x, y) = (260.66, 58.04), Wall Distance = 20.50 nm
# Iteration 27100: Position (x, y) = (260.65, 57.93), Wall Distance = 20.50 nm
# Iteration 27200: Position (x, y) = (260.64, 57.81), Wall Distance = 20.50 nm
# Iteration 27300: Position (x, y) = (260.62, 57.70), Wall Distance = 20.50 nm
# Iteration 27400: Position (x, y) = (260.61, 57.59), Wall Distance = 20.50 nm
# Iteration 27500: Position (x, y) = (260.59, 57.47), Wall Distance = 20.50 nm
# Iteration 27600: Position (x, y) = (260.58, 57.35), Wall Distance = 20.50 nm
# Iteration 27700: Position (x, y) = (260.56, 57.24), Wall Distance = 20.50 nm
# Iteration 27800: Position (x, y) = (260.55, 57.12), Wall Distance = 20.50 nm
# Iteration 27900: Position (x, y) = (260.53, 57.00), Wall Distance = 20.50 nm
# Iteration 28000: Position (x, y) = (260.52, 56.88), Wall Distance = 20.50 nm
# Iteration 28100: Position (x, y) = (260.50, 56.76), Wall Distance = 20.50 nm
# Iteration 28200: Position (x, y) = (260.49, 56.63), Wall Distance = 20.50 nm
# Iteration 28300: Position (x, y) = (260.47, 56.51), Wall Distance = 20.50 nm
# Iteration 28400: Position (x, y) = (260.46, 56.39), Wall Distance = 20.50 nm
# Iteration 28500: Position (x, y) = (260.44, 56.26), Wall Distance = 20.50 nm
# Iteration 28600: Position (x, y) = (260.43, 56.14), Wall Distance = 20.50 nm
# Iteration 28700: Position (x, y) = (260.42, 56.01), Wall Distance = 20.50 nm
# Iteration 28800: Position (x, y) = (260.40, 55.88), Wall Distance = 20.50 nm
# Iteration 28900: Position (x, y) = (260.39, 55.75), Wall Distance = 20.50 nm
# Iteration 29000: Position (x, y) = (260.37, 55.62), Wall Distance = 20.50 nm
# Iteration 29100: Position (x, y) = (260.36, 55.49), Wall Distance = 20.50 nm
# Iteration 29200: Position (x, y) = (260.34, 55.36), Wall Distance = 20.50 nm
# Iteration 29300: Position (x, y) = (260.33, 55.23), Wall Distance = 20.50 nm
# Iteration 29400: Position (x, y) = (260.31, 55.10), Wall Distance = 20.50 nm
# Iteration 29500: Position (x, y) = (260.30, 54.96), Wall Distance = 20.50 nm
# Iteration 29600: Position (x, y) = (260.29, 54.83), Wall Distance = 20.50 nm
# Iteration 29700: Position (x, y) = (260.27, 54.69), Wall Distance = 20.50 nm
# Iteration 29800: Position (x, y) = (260.26, 54.55), Wall Distance = 20.50 nm
# Iteration 29900: Position (x, y) = (260.24, 54.42), Wall Distance = 20.50 nm
# Iteration 30000: Position (x, y) = (260.23, 54.28), Wall Distance = 20.50 nm
# Iteration 30100: Position (x, y) = (260.21, 54.14), Wall Distance = 20.50 nm
# Iteration 30200: Position (x, y) = (260.20, 54.00), Wall Distance = 20.50 nm
# Iteration 30300: Position (x, y) = (260.19, 53.86), Wall Distance = 20.50 nm
# Iteration 30400: Position (x, y) = (260.17, 53.71), Wall Distance = 20.50 nm
# Iteration 30500: Position (x, y) = (260.16, 53.57), Wall Distance = 20.50 nm
# Iteration 30600: Position (x, y) = (260.14, 53.42), Wall Distance = 20.50 nm
# Iteration 30700: Position (x, y) = (260.13, 53.28), Wall Distance = 20.50 nm
# Iteration 30800: Position (x, y) = (260.12, 53.13), Wall Distance = 20.50 nm
# Iteration 30900: Position (x, y) = (260.10, 52.99), Wall Distance = 20.50 nm
# Iteration 31000: Position (x, y) = (260.09, 52.84), Wall Distance = 20.50 nm
# Iteration 31100: Position (x, y) = (260.08, 52.69), Wall Distance = 20.50 nm
# Iteration 31200: Position (x, y) = (260.06, 52.54), Wall Distance = 20.50 nm
# Iteration 31300: Position (x, y) = (260.05, 52.39), Wall Distance = 20.50 nm
# Iteration 31400: Position (x, y) = (260.04, 52.24), Wall Distance = 20.50 nm
# Iteration 31500: Position (x, y) = (260.02, 52.08), Wall Distance = 20.50 nm
# Iteration 31600: Position (x, y) = (260.01, 51.93), Wall Distance = 20.50 nm
# Iteration 31700: Position (x, y) = (259.99, 51.78), Wall Distance = 20.50 nm
# Iteration 31800: Position (x, y) = (259.98, 51.62), Wall Distance = 20.50 nm
# Iteration 31900: Position (x, y) = (259.97, 51.46), Wall Distance = 20.50 nm
# Iteration 32000: Position (x, y) = (259.96, 51.30), Wall Distance = 20.50 nm
# Iteration 32100: Position (x, y) = (259.94, 51.15), Wall Distance = 20.50 nm
# Iteration 32200: Position (x, y) = (259.93, 50.99), Wall Distance = 20.50 nm
# Iteration 32300: Position (x, y) = (259.92, 50.83), Wall Distance = 20.50 nm
# Iteration 32400: Position (x, y) = (259.91, 50.67), Wall Distance = 20.50 nm
# Iteration 32500: Position (x, y) = (259.89, 50.50), Wall Distance = 20.50 nm
# Iteration 32600: Position (x, y) = (259.88, 50.34), Wall Distance = 20.50 nm
# Iteration 32700: Position (x, y) = (259.87, 50.18), Wall Distance = 20.50 nm
# Iteration 32800: Position (x, y) = (259.86, 50.01), Wall Distance = 20.50 nm
# Iteration 32900: Position (x, y) = (259.85, 49.85), Wall Distance = 20.50 nm
# Iteration 33000: Position (x, y) = (259.83, 49.68), Wall Distance = 20.50 nm
# Iteration 33100: Position (x, y) = (259.82, 49.51), Wall Distance = 20.50 nm
# Iteration 33200: Position (x, y) = (259.81, 49.34), Wall Distance = 20.50 nm
# Iteration 33300: Position (x, y) = (259.80, 49.17), Wall Distance = 20.50 nm
# Iteration 33400: Position (x, y) = (259.79, 49.00), Wall Distance = 20.50 nm
# Iteration 33500: Position (x, y) = (259.78, 48.83), Wall Distance = 20.50 nm
# Iteration 33600: Position (x, y) = (259.77, 48.66), Wall Distance = 20.50 nm
# Iteration 33700: Position (x, y) = (259.76, 48.49), Wall Distance = 20.50 nm
# Iteration 33800: Position (x, y) = (259.75, 48.32), Wall Distance = 20.50 nm
# Iteration 33900: Position (x, y) = (259.74, 48.14), Wall Distance = 20.50 nm
# Iteration 34000: Position (x, y) = (259.73, 47.97), Wall Distance = 20.50 nm
# Iteration 34100: Position (x, y) = (259.72, 47.79), Wall Distance = 20.50 nm
# Iteration 34200: Position (x, y) = (259.71, 47.61), Wall Distance = 20.50 nm
# Iteration 34300: Position (x, y) = (259.70, 47.43), Wall Distance = 20.50 nm
# Iteration 34400: Position (x, y) = (259.69, 47.25), Wall Distance = 20.50 nm
# Iteration 34500: Position (x, y) = (259.68, 47.08), Wall Distance = 20.50 nm
# Iteration 34600: Position (x, y) = (259.67, 46.89), Wall Distance = 20.50 nm
# Iteration 34700: Position (x, y) = (259.66, 46.71), Wall Distance = 20.50 nm
# Iteration 34800: Position (x, y) = (259.65, 46.53), Wall Distance = 20.50 nm
# Iteration 34900: Position (x, y) = (259.64, 46.35), Wall Distance = 20.50 nm
# Iteration 35000: Position (x, y) = (259.64, 46.16), Wall Distance = 20.50 nm
# Iteration 35100: Position (x, y) = (259.63, 45.98), Wall Distance = 20.50 nm
# Iteration 35200: Position (x, y) = (259.62, 45.79), Wall Distance = 20.50 nm
# Iteration 35300: Position (x, y) = (259.61, 45.60), Wall Distance = 20.50 nm
# Iteration 35400: Position (x, y) = (259.61, 45.42), Wall Distance = 20.50 nm
# Iteration 35500: Position (x, y) = (259.60, 45.23), Wall Distance = 20.50 nm
# Iteration 35600: Position (x, y) = (259.59, 45.04), Wall Distance = 20.50 nm
# Iteration 35700: Position (x, y) = (259.58, 44.85), Wall Distance = 20.50 nm
# Iteration 35800: Position (x, y) = (259.58, 44.66), Wall Distance = 20.50 nm
# Iteration 35900: Position (x, y) = (259.57, 44.47), Wall Distance = 20.50 nm
# Iteration 36000: Position (x, y) = (259.57, 44.28), Wall Distance = 20.50 nm
# Iteration 36100: Position (x, y) = (259.56, 44.08), Wall Distance = 20.50 nm
# Iteration 36200: Position (x, y) = (259.55, 43.89), Wall Distance = 20.50 nm
# Iteration 36300: Position (x, y) = (259.55, 43.70), Wall Distance = 20.50 nm
# Iteration 36400: Position (x, y) = (259.54, 43.50), Wall Distance = 20.50 nm
# Iteration 36500: Position (x, y) = (259.54, 43.31), Wall Distance = 20.50 nm
# Iteration 36600: Position (x, y) = (259.53, 43.11), Wall Distance = 20.50 nm
# Iteration 36700: Position (x, y) = (259.53, 42.91), Wall Distance = 20.50 nm
# Iteration 36800: Position (x, y) = (259.53, 42.71), Wall Distance = 20.50 nm
# Iteration 36900: Position (x, y) = (259.52, 42.51), Wall Distance = 20.50 nm
# Iteration 37000: Position (x, y) = (259.52, 42.32), Wall Distance = 20.50 nm
# Iteration 37100: Position (x, y) = (259.52, 42.11), Wall Distance = 20.50 nm
# Iteration 37200: Position (x, y) = (259.51, 41.91), Wall Distance = 20.50 nm
# Iteration 37300: Position (x, y) = (259.51, 41.71), Wall Distance = 20.50 nm
# Iteration 37400: Position (x, y) = (259.51, 41.51), Wall Distance = 20.50 nm
# Iteration 37500: Position (x, y) = (259.51, 41.31), Wall Distance = 20.50 nm
# Iteration 37600: Position (x, y) = (259.51, 41.10), Wall Distance = 20.50 nm
# Iteration 37700: Position (x, y) = (259.50, 40.90), Wall Distance = 20.50 nm
# Iteration 37800: Position (x, y) = (259.50, 40.69), Wall Distance = 20.50 nm
# Iteration 37900: Position (x, y) = (259.50, 40.48), Wall Distance = 20.50 nm
# Iteration 38000: Position (x, y) = (259.50, 40.28), Wall Distance = 20.50 nm
# Iteration 38100: Position (x, y) = (259.50, 40.07), Wall Distance = 20.50 nm
# Iteration 38200: Position (x, y) = (259.50, 39.86), Wall Distance = 20.50 nm
# Iteration 38300: Position (x, y) = (259.50, 39.65), Wall Distance = 20.50 nm
# Iteration 38400: Position (x, y) = (259.50, 39.44), Wall Distance = 20.50 nm
# Iteration 38500: Position (x, y) = (259.50, 39.23), Wall Distance = 20.50 nm
# Iteration 38600: Position (x, y) = (259.50, 39.02), Wall Distance = 20.50 nm
# Iteration 38700: Position (x, y) = (259.51, 38.81), Wall Distance = 20.50 nm
# Iteration 38800: Position (x, y) = (259.51, 38.60), Wall Distance = 20.50 nm
# Iteration 38900: Position (x, y) = (259.51, 38.39), Wall Distance = 20.50 nm
# Iteration 39000: Position (x, y) = (259.51, 38.17), Wall Distance = 20.50 nm
# Iteration 39100: Position (x, y) = (259.52, 37.96), Wall Distance = 20.50 nm
# Iteration 39200: Position (x, y) = (259.52, 37.75), Wall Distance = 20.50 nm
# Iteration 39300: Position (x, y) = (259.52, 37.53), Wall Distance = 20.50 nm
# Iteration 39400: Position (x, y) = (259.53, 37.32), Wall Distance = 20.50 nm
# Iteration 39500: Position (x, y) = (259.53, 37.10), Wall Distance = 20.50 nm
# Iteration 39600: Position (x, y) = (259.54, 36.88), Wall Distance = 20.50 nm
# Iteration 39700: Position (x, y) = (259.54, 36.67), Wall Distance = 20.50 nm
# Iteration 39800: Position (x, y) = (259.55, 36.45), Wall Distance = 20.50 nm
# Iteration 39900: Position (x, y) = (259.55, 36.23), Wall Distance = 20.50 nm
# Iteration 40000: Position (x, y) = (259.56, 36.01), Wall Distance = 20.50 nm
# Iteration 40100: Position (x, y) = (259.56, 35.79), Wall Distance = 20.50 nm
# Iteration 40200: Position (x, y) = (259.57, 35.57), Wall Distance = 20.50 nm
# Iteration 40300: Position (x, y) = (259.58, 35.35), Wall Distance = 20.50 nm
# Iteration 40400: Position (x, y) = (259.58, 35.13), Wall Distance = 20.50 nm
# Iteration 40500: Position (x, y) = (259.59, 34.91), Wall Distance = 20.50 nm
# Iteration 40600: Position (x, y) = (259.60, 34.68), Wall Distance = 20.50 nm
# Iteration 40700: Position (x, y) = (259.61, 34.46), Wall Distance = 20.50 nm
# Iteration 40800: Position (x, y) = (259.62, 34.24), Wall Distance = 20.50 nm
# Iteration 40900: Position (x, y) = (259.63, 34.01), Wall Distance = 20.50 nm
# Iteration 41000: Position (x, y) = (259.64, 33.79), Wall Distance = 20.50 nm
# Iteration 41100: Position (x, y) = (259.65, 33.57), Wall Distance = 20.50 nm
# Iteration 41200: Position (x, y) = (259.66, 33.34), Wall Distance = 20.50 nm
# Iteration 41300: Position (x, y) = (259.67, 33.11), Wall Distance = 20.50 nm
# Iteration 41400: Position (x, y) = (259.68, 32.89), Wall Distance = 20.50 nm
# Iteration 41500: Position (x, y) = (259.69, 32.66), Wall Distance = 20.50 nm
# Iteration 41600: Position (x, y) = (259.70, 32.44), Wall Distance = 20.50 nm
# Iteration 41700: Position (x, y) = (259.72, 32.21), Wall Distance = 20.50 nm
# Iteration 41800: Position (x, y) = (259.73, 31.98), Wall Distance = 20.50 nm
# Iteration 41900: Position (x, y) = (259.74, 31.75), Wall Distance = 20.50 nm
# Iteration 42000: Position (x, y) = (259.76, 31.52), Wall Distance = 20.50 nm
# Iteration 42100: Position (x, y) = (259.77, 31.29), Wall Distance = 20.50 nm
# Iteration 42200: Position (x, y) = (259.79, 31.06), Wall Distance = 20.50 nm
# Iteration 42300: Position (x, y) = (259.80, 30.83), Wall Distance = 20.50 nm
# Iteration 42400: Position (x, y) = (259.82, 30.60), Wall Distance = 20.50 nm
# Iteration 42500: Position (x, y) = (259.83, 30.37), Wall Distance = 20.50 nm
# Iteration 42600: Position (x, y) = (259.85, 30.14), Wall Distance = 20.50 nm
# Iteration 42700: Position (x, y) = (259.86, 29.91), Wall Distance = 20.50 nm
# Iteration 42800: Position (x, y) = (259.88, 29.68), Wall Distance = 20.50 nm
# Iteration 42900: Position (x, y) = (259.90, 29.44), Wall Distance = 20.50 nm
# Iteration 43000: Position (x, y) = (259.92, 29.21), Wall Distance = 20.50 nm
# Iteration 43100: Position (x, y) = (259.93, 28.98), Wall Distance = 20.50 nm
# Iteration 43200: Position (x, y) = (259.95, 28.74), Wall Distance = 20.50 nm
# Iteration 43300: Position (x, y) = (259.97, 28.49), Wall Distance = 20.50 nm
# Iteration 43400: Position (x, y) = (260.00, 28.22), Wall Distance = 20.50 nm
# Iteration 43500: Position (x, y) = (260.02, 27.96), Wall Distance = 20.50 nm
# Iteration 43600: Position (x, y) = (260.04, 27.69), Wall Distance = 20.50 nm
# Iteration 43700: Position (x, y) = (260.06, 27.42), Wall Distance = 20.50 nm
# Iteration 43800: Position (x, y) = (260.09, 27.16), Wall Distance = 20.50 nm
# Iteration 43900: Position (x, y) = (260.11, 26.89), Wall Distance = 20.50 nm
# Iteration 44000: Position (x, y) = (260.14, 26.62), Wall Distance = 20.50 nm
# Iteration 44100: Position (x, y) = (260.16, 26.35), Wall Distance = 20.50 nm
# Iteration 44200: Position (x, y) = (260.19, 26.09), Wall Distance = 20.50 nm
# Total simulation time: 45.85 seconds
